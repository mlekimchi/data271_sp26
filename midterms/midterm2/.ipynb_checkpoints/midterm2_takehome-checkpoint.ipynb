# %% [markdown]
# # DATA 271 — Midterm 2: Take-Home Project Notebook
# **Spring 2026 | Instructor: Emily Chang | Due: Monday, April 7, 2026 by 11:59 PM**
#
# ---
#
# ## How this fits into your final project
#
# This notebook is a **direct continuation** of your two check-ins. You are not starting over — you are building on what you have already submitted.
#
# | What you already completed | Final project section |
# |---------------------------|-----------------------|
# | Check-in 1: Load data · `.info()` · `.describe()` · `.shape` | §3 Data Preparation (start) |
# | Check-in 2: Introduction + dataset description | §1 Introduction · §3.1–3.2 |
# | **This take-home: Libraries → Cleaning → EDA → Summary** | **§2 · §3 (finish) · §4 · §5** |
#
# When you submit this, you will have completed roughly **60–70% of your final project** — graded and feedbacked before the final deadline.
#
# ---
#
# ## Rules
#
# - Work independently — this is an exam
# - You may use your notes, lecture notebooks, and library documentation (Pandas, Seaborn, Matplotlib, plotnine)
# - You may **not** use AI tools to write your code or analysis
# - Every code cell must have a markdown cell providing context — before, after, or both
# - Run **Kernel → Restart & Run All** before submitting — your notebook must execute top-to-bottom without errors
# - Submit to Canvas as `.ipynb` **and** push to your GitHub repo
#
# ---
#
# ## 📋 Grader's Checklist
#
# *Students: complete this before submitting. Fill in ✓ or ✗ for each row.*
#
# | # | Section | Requirement | ✓ / ✗ |
# |---|---------|-------------|-------|
# | 1 | §2 Libraries | All imports in one cell + markdown table explaining each library | |
# | 2 | §3.1 Cleaning | ≥3 cleaning steps, each with markdown explaining what and why | |
# | 3 | §3.2 Final dataset | Cleaned dataset shown in condensed form (`.head()` or `.info()`) | |
# | 4 | §3.3 Summary stats | `.describe()` or table + 2–3 sentence written interpretation | |
# | 5 | §4.1 New column 1 | Conditional column (`np.where` / boolean) + markdown explanation | |
# | 6 | §4.1 New column 2 | String / arithmetic / datetime column + markdown explanation | |
# | 7 | §4.2 Visualization 1 | Plot + title + axis labels + 2–3 sentence interpretation | |
# | 8 | §4.3 Visualization 2 | **Faceted or grouped** plot + title + labels + interpretation | |
# | 9 | §4.4 Visualization 3 | Plot + title + axis labels + 2–3 sentence interpretation | |
# | 10 | §4.5 Grouped analysis | `groupby` + aggregation + visualization + written subgroup finding | |
# | 11 | §5 Running summary | ≥2 specific findings + ≥2 open questions named | |
# | 12 | Format | Markdown between code cells · runs clean · GitHub link visible | |
# | Bonus | §6 API enrichment | API call + new column added + explanation | |
#
# ---
#
# ## Point Summary
#
# | Section | Points |
# |---------|--------|
# | §2 Libraries | 5 |
# | §3 Data Preparation (3.1 + 3.2 + 3.3) | 20 |
# | §4.1 Column engineering | 15 |
# | §4.2–4.4 Visualizations (3 plots) | 20 |
# | §4.5 Grouped analysis | 10 |
# | §5 Running summary | 5 |
# | **Total** | **75** |
# | §6 API enrichment *(bonus)* | +5 |
#
# ---

# %% [markdown]
# ---
# # §2 — Required Libraries
# **5 points** `→ Final project §2`
#
# List every library you will use in this notebook and explain in one sentence why it is necessary. Then import them all in the single code cell below.
#
# > **Why this matters:** A reader should be able to open your notebook and immediately know what to install and run your analysis. Keep all imports in one place — do not import libraries mid-notebook.

# %% [markdown]
# **Libraries used in this notebook:**
#
# | Library | Purpose |
# |---------|---------|
# | `pandas` | *(explain why)* |
# | `numpy` | *(explain why)* |
# | `seaborn` or `plotnine` | *(explain why)* |
# | `matplotlib.pyplot` | *(explain why)* |
# | *(add rows as needed)* | |

# %%
# All imports — do not import anywhere else in the notebook
import pandas as pd
import numpy as np

# Add your visualization and other imports below:

# %% [markdown]
# ---
# # §3 — Data Preparation
# **20 points** `→ Final project §3`
#
# *Your data should already be loaded from Check-in 1. This section finishes the cleaning, displays the final cleaned dataset, and summarizes its key features.*

# %% [markdown]
# ## §3.1 — Finish Cleaning
# **10 points**
#
# Complete the cleaning process you started in Check-in 1. Address **at least 3** of the following (whichever apply to your dataset):
#
# - **Rename columns** — unclear or machine-generated names → readable lowercase with underscores
# - **Fix data types** — year stored as float → int; date string → datetime; numeric stored as object
# - **Handle missing values** — drop, fill, or flag nulls; explain your choice for each column
# - **Remove duplicate rows** — if present
# - **Reshape** — wide → long with `.melt()`, or long → wide with `.pivot_table()`
# - **Filter** — remove rows outside your analysis scope (e.g., out-of-range years, placeholder values)
#
# > For **each step**: write a markdown cell first explaining *what* the problem is and *why* you are fixing it this way. Then write the code. This is exactly what the final project rubric (§3.3) requires.

# %% [markdown]
# **Cleaning step 1 — describe the problem and your approach:**
#
# *(write here)*

# %%
# Cleaning step 1:

# %% [markdown]
# **Cleaning step 2 — describe the problem and your approach:**
#
# *(write here)*

# %%
# Cleaning step 2:

# %% [markdown]
# **Cleaning step 3 — describe the problem and your approach:**
#
# *(write here)*
#
# *(Add more §3.1 cells as needed)*

# %%
# Cleaning step 3:

# %% [markdown]
# ## §3.2 — Final Cleaned Dataset
# **5 points**
#
# Show the final state of your cleaned dataset in the most **condensed** form possible — a `.head()`, `.info()`, or a small summary table. Do not print a full DataFrame with hundreds of rows.

# %%
# Show final cleaned dataset (condensed):

# %% [markdown]
# ## §3.3 — Summary Statistics
# **5 points**
#
# Use `.describe()` and/or a summary table to characterize the variables most relevant to your research question.
#
# Then write **2–3 sentences** interpreting what the numbers tell you: What stands out? Any outliers, surprising ranges, or heavily skewed distributions?

# %%
# Summary statistics:

# %% [markdown]
# **Interpretation (2–3 sentences):**
#
# *(write here)*

# %% [markdown]
# ---
# # §4 — Exploratory Data Analysis
# **45 points** `→ Final project §4`
#
# *This is the core of your project. You are not just describing the data — you are uncovering patterns and insights that connect back to your research question.*

# %% [markdown]
# ## §4.1 — Engineer New Variables
# **15 points**
#
# Create at least **2 new columns** that help you answer your research question. For each one, write a markdown cell explaining what the column is and why it is analytically useful.
#
# - **Column 1 — conditional:** Use `np.where()`, boolean masking, or `.apply()` with a condition. Examples: a binary flag, a tier/group label derived from a threshold, a category computed from existing values.
# - **Column 2 — string, arithmetic, or datetime:** Use a string method, a calculation, or a datetime extraction. Examples: extract the year from a date column, compute a rate or ratio, parse a state abbreviation from an address string.

# %% [markdown]
# **New Column 1 — conditional**
#
# *What is this column? How does it help answer your research question?*
#
# *(write here)*

# %%
# New column 1 (conditional):

# %% [markdown]
# **New Column 2 — string / arithmetic / datetime**
#
# *What is this column? How does it help answer your research question?*
#
# *(write here)*

# %%
# New column 2 (string / arithmetic / datetime):

# %%
# Confirm both new columns appear in your DataFrame:

# %% [markdown]
# ## §4.2 — Visualization 1
# **~7 points**
#
# > **Before you code:** What is the *one specific question* this plot answers? Write it below, then make the plot.
#
# Requirements: title · axis labels · legend if multiple groups are shown · 2–3 sentence interpretation after the plot.

# %% [markdown]
# *What question does this plot answer?*
#
# *(write here)*

# %%
# Visualization 1:

# %% [markdown]
# **Interpretation (2–3 sentences):** What does this plot tell you about your research question?
#
# *(write here)*

# %% [markdown]
# ## §4.3 — Visualization 2 *(must be faceted or grouped)*
# **~7 points**
#
# This plot must break the data into subgroups. Use `hue=`, `col=`, or `row=` in Seaborn, or `facet_wrap()` / `facet_grid()` in plotnine.
#
# > **Before you code:** What subgroup comparison are you making, and why is it meaningful for your research question?

# %% [markdown]
# *What subgroup comparison does this plot make? Why is this comparison meaningful?*
#
# *(write here)*

# %%
# Visualization 2 (faceted or grouped — required):

# %% [markdown]
# **Interpretation (2–3 sentences):** What does the subgroup comparison reveal? Does it change your understanding?
#
# *(write here)*

# %% [markdown]
# ## §4.4 — Visualization 3
# **~6 points**
#
# > **Before you code:** What is the one specific question this plot answers?

# %% [markdown]
# *What question does this plot answer?*
#
# *(write here)*

# %%
# Visualization 3:

# %% [markdown]
# **Interpretation (2–3 sentences):** What does this plot tell you?
#
# *(write here)*

# %% [markdown]
# ## §4.5 — Grouped Analysis
# **10 points**
#
# Use `.groupby()` and an aggregation function (`.mean()`, `.sum()`, `.count()`, `.median()`, etc.) to summarize your data along a meaningful dimension. Visualize the result, then write your finding.
#
# > **Think subgroups:** Do different regions, time periods, demographic categories, or data types behave differently in your dataset? This is how you find out.
#
# > **Tip:** Sort your result with `.sort_values()` before plotting when there are many groups — it makes the chart much more readable.

# %% [markdown]
# *What are you grouping by? What are you measuring within each group? Why is this the right question to ask for your project?*
#
# *(write here)*

# %%
# Grouped aggregation:

# %%
# Visualization of grouped result:

# %% [markdown]
# **Subgroup finding (2–3 sentences):** Which group stands out? What does this pattern mean for your research question?
#
# *(write here)*

# %% [markdown]
# ---
# # §5 — Running Summary
# **5 points** `→ Final project §5 (early draft)`
#
# Write **1–2 paragraphs** capturing where your project stands right now:
#
# 1. **Findings so far** — Describe at least **2 specific patterns or insights** from §4. Reference your actual results with numbers or group names where possible.
# 2. **Open questions** — Name at least **2 questions your final project still needs to answer.** These become your roadmap for the coming weeks.
#
# > This is a working draft of your final project's Summary section. The structure and open questions you define here will guide your remaining analysis.

# %% [markdown]
# *(Write your 1–2 paragraph running summary here)*

# %% [markdown]
# ---
# # §6 — API Enrichment *(Optional — +5 bonus points)*
# `→ Final project §3 (data enrichment)`
#
# Use an external API to add at least **1 new column** to your dataset from an outside source. See `task7_api_worked_example.ipynb` for step-by-step instructions and a table of API recommendations by dataset type (cancer, census, sports/gambling, and more).
#
# **Show all 4 steps to receive full bonus credit:**

# %% [markdown]
# *Which API are you using? What new information will it add to your dataset?*
#
# *(write here)*

# %%
# Step 1: Test the API on one item — confirm it works before looping

# %%
# Step 2: Loop over unique values in your column

# %%
# Step 3: Map results back into your DataFrame as a new column

# %%
# Step 4: Show .head() with the new column visible

# %% [markdown]
# **What did you add and how will it be useful in your final project?**
#
# *(write here)*

# %% [markdown]
# ---
# # ✅ Before You Submit
#
# 1. Go back to the **Grader's Checklist** at the top and fill in every ✓ / ✗
# 2. Run **Kernel → Restart & Run All** — the notebook must execute completely without errors
# 3. Make sure your **GitHub repo link** is visible somewhere in the notebook
# 4. Download as `.ipynb` and submit to **Canvas**
# 5. **Push** the updated notebook to your **GitHub repo**
