# %%
import numpy as np

# %% [markdown]
# Create the array below by using numpy and without manually inputing the numbers as lists. After creating the array, create another array named array_sorted to sort it by column.
#
# $\begin{bmatrix}
# 2 & 4 & 6 & 8 & 10\\
# 3 & 6 & 9 & 12 & 15\\
# 1 & 2 & 3 & 4 & 5
# \end{bmatrix}$

# %%
array1 = ...
array_sorted = ...
array_sorted
# Out:
# Ellipsis

# %% [markdown]
# ANSWER
#
# array1 = np.array([np.arange(2, 11, 2), np.arange(3, 16, 3), np.arange(1, 6))
#
# array_sorted = np.sort(array1, axis=0)
#
# array_sorted
