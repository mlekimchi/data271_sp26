# %% [markdown]
# Given 'numbers', make a list of the squares of each of the numbers in 'numbers' that is greater than 10.

# %%
numbers = [3, 12, 7, 18, 5, 20, 9]
squares=...
squares
# Out:
# Ellipsis

# %% [markdown]
# Answer:

# %%
squares = [x**2 for x in numbers if x > 10]
print(squares)
# Out:
# [144, 324, 400]
