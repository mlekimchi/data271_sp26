# %% [markdown]
# # Final Project Presentation!

# %%
import random

students = [
    "Dennis Allen",
    "Alex Alvarez",
    "Joey Araujo",
    "Justin Arellano",
    "Lucca Barsotti",
    "Carla Esparza",
    "Joseph Hildebrandt",
    "Nyi Htun",
    "Jacob Lewis",
    "Yisak Mulugeta",
    "Paige Murray",
    "Katayoon Seraji Nezhad",
    "Emir Sicairos",
    "Colin Trevino-Odell",
    "Iris Yeaney"
]

# Make a random presentation order
presentation_order = students.copy()
random.shuffle(presentation_order)

presentation_order
# Out:
# ['Iris Yeaney',
#  'Alex Alvarez',
#  'Lucca Barsotti',
#  'Justin Arellano',
#  'Carla Esparza',
#  'Colin Trevino-Odell',
#  'Joey Araujo',
#  'Dennis Allen',
#  'Nyi Htun',
#  'Katayoon Seraji Nezhad',
#  'Jacob Lewis',
#  'Joseph Hildebrandt',
#  'Paige Murray',
#  'Yisak Mulugeta',
#  'Emir Sicairos']

# %%
if len(presentation_order) > 0:
    next_student = presentation_order.pop(0)
    print("Next presenter:", next_student)
    print("Students remaining:", len(presentation_order))
else:
    print("Everyone has presented!")
# Out:
# Next presenter: Iris Yeaney
# Students remaining: 14
