# %% [markdown]
# # Animations and Tidy Data
# If you want to type along with me, use [this notebook](https://humboldt.cloudbank.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fbethanyj0%2Fdata271_sp25&branch=main&urlpath=tree%2Fdata271_sp25%2Flectures%2Fdata271_lec35_live.ipynb) instead.
# If you don't want to type and want to follow along just by executing the cells, stay in this notebook.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from ipywidgets import interact
import ipywidgets as widgets

# %% [markdown]
# ### Animations/sliders with plotly

# %%
# Import the gap minder
df = pd.read_csv('gapminder_all.csv')
df
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
#      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0       3246.991771     4182.663766     4910.416756     5745.160213
# 1       5522.776375     5473.288005     3008.647355     2756.953672
# 2       1035.831411     1085.796879     1029.161251     1277.897616
# 3       1214.709294     2263.611114     3214.857818     4551.142150
# 4        794.826560      854.735976      743.387037      807.198586
# ..              ...             ...             ...             ...
# 137    22966.144320    27195.113040    26982.290520    28397.715120
# 138     2826.356387     3450.696380     4269.122326     4241.356344
# 139    14142.850890    15895.116410    17428.748460    18232.424520
# 140    14526.124650    16788.629480    18334.197510    19477.009280
# 141    14463.918930    16046.037280    16233.717700    17632.410400
#
#      gdpPercap_1987  ...    pop_1962    pop_1967    pop_1972    pop_1977  \
# 0       5681.358539  ...  11000948.0  12760499.0  14760787.0  17152804.0
# 1       2430.208311  ...   4826015.0   5247469.0   5894858.0   6162675.0
# 2       1225.856010  ...   2151895.0   2427334.0   2761407.0   3168267.0
# 3       6205.883850  ...    512764.0    553541.0    619351.0    781472.0
# 4        912.063142  ...   4919632.0   5127935.0   5433886.0   5889574.0
# ..              ...  ...         ...         ...         ...         ...
# 137    30281.704590  ...   5666000.0   6063000.0   6401400.0   6316424.0
# 138     5089.043686  ...  29788695.0  33411317.0  37492953.0  42404033.0
# 139    21664.787670  ...  53292000.0  54959000.0  56079000.0  56179000.0
# 140    21888.889030  ...  10794968.0  11872264.0  13177000.0  14074100.0
# 141    19007.191290  ...   2488550.0   2728150.0   2929100.0   3164900.0
#
#        pop_1982    pop_1987    pop_1992    pop_1997  pop_2002  pop_2007
# 0    20033753.0  23254956.0  26298373.0  29072015.0  31287142  33333216
# 1     7016384.0   7874230.0   8735988.0   9875024.0  10866106  12420476
# 2     3641603.0   4243788.0   4981671.0   6066080.0   7026113   8078314
# 3      970347.0   1151184.0   1342614.0   1536536.0   1630347   1639131
# 4     6634596.0   7586551.0   8878303.0  10352843.0  12251209  14326203
# ..          ...         ...         ...         ...       ...       ...
# 137   6468126.0   6649942.0   6995447.0   7193761.0   7361757   7554661
# 138  47328791.0  52881328.0  58179144.0  63047647.0  67308928  71158647
# 139  56339704.0  56981620.0  57866349.0  58808266.0  59912431  60776238
# 140  15184200.0  16257249.0  17481977.0  18565243.0  19546792  20434176
# 141   3210650.0   3317166.0   3437674.0   3676187.0   3908037   4115771
#
# [142 rows x 38 columns]

# %%
# Tidy the data (start by melting)
long_df = df.melt(id_vars=['continent','country'])
long_df
# Out:
#      continent         country        variable         value
# 0       Africa         Algeria  gdpPercap_1952  2.449008e+03
# 1       Africa          Angola  gdpPercap_1952  3.520610e+03
# 2       Africa           Benin  gdpPercap_1952  1.062752e+03
# 3       Africa        Botswana  gdpPercap_1952  8.512411e+02
# 4       Africa    Burkina Faso  gdpPercap_1952  5.432552e+02
# ...        ...             ...             ...           ...
# 5107    Europe     Switzerland        pop_2007  7.554661e+06
# 5108    Europe          Turkey        pop_2007  7.115865e+07
# 5109    Europe  United Kingdom        pop_2007  6.077624e+07
# 5110   Oceania       Australia        pop_2007  2.043418e+07
# 5111   Oceania     New Zealand        pop_2007  4.115771e+06
#
# [5112 rows x 4 columns]

# %%
# Each variable gets its own column
long_df[['var','year']] = long_df.variable.str.split('_',expand=True)
long_df.drop(columns = 'variable',inplace=True)
long_df
# Out:
#      continent         country         value        var  year
# 0       Africa         Algeria  2.449008e+03  gdpPercap  1952
# 1       Africa          Angola  3.520610e+03  gdpPercap  1952
# 2       Africa           Benin  1.062752e+03  gdpPercap  1952
# 3       Africa        Botswana  8.512411e+02  gdpPercap  1952
# 4       Africa    Burkina Faso  5.432552e+02  gdpPercap  1952
# ...        ...             ...           ...        ...   ...
# 5107    Europe     Switzerland  7.554661e+06        pop  2007
# 5108    Europe          Turkey  7.115865e+07        pop  2007
# 5109    Europe  United Kingdom  6.077624e+07        pop  2007
# 5110   Oceania       Australia  2.043418e+07        pop  2007
# 5111   Oceania     New Zealand  4.115771e+06        pop  2007
#
# [5112 rows x 5 columns]

# %%
# pivot so each variable is a column
tidy_df = long_df.pivot_table(index = ['continent','country','year'],
                              columns='var',values='value').reset_index()
tidy_df
# Out:
# var  continent      country  year     gdpPercap  lifeExp         pop
# 0       Africa      Algeria  1952   2449.008185   43.077   9279525.0
# 1       Africa      Algeria  1957   3013.976023   45.685  10270856.0
# 2       Africa      Algeria  1962   2550.816880   48.303  11000948.0
# 3       Africa      Algeria  1967   3246.991771   51.407  12760499.0
# 4       Africa      Algeria  1972   4182.663766   54.518  14760787.0
# ...        ...          ...   ...           ...      ...         ...
# 1699   Oceania  New Zealand  1987  19007.191290   74.320   3317166.0
# 1700   Oceania  New Zealand  1992  18363.324940   76.330   3437674.0
# 1701   Oceania  New Zealand  1997  21050.413770   77.550   3676187.0
# 1702   Oceania  New Zealand  2002  23189.801350   79.110   3908037.0
# 1703   Oceania  New Zealand  2007  25185.009110   80.204   4115771.0
#
# [1704 rows x 6 columns]

# %%
# check info for datatypes and nulls
tidy_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  1704 non-null   str
#  1   country    1704 non-null   str
#  2   year       1704 non-null   str
#  3   gdpPercap  1704 non-null   float64
#  4   lifeExp    1704 non-null   float64
#  5   pop        1704 non-null   float64
# dtypes: float64(3), str(3)
# memory usage: 80.0 KB

# %%
# cast year to type int
tidy_df['year'] = tidy_df.year.astype(int)

# %% [markdown]
# ### How would we visualize with Seaborn?

# %%
# scatterplot in seaborn for one year
sns.scatterplot(data = tidy_df[tidy_df['year']== 2007],
                x = 'gdpPercap',y='lifeExp',size='pop', 
                sizes=(25, 250), hue='continent',alpha=0.7)
plt.xscale('log')

# %%
# Show the trend across years
sns.relplot(data = tidy_df,x = 'gdpPercap',y='lifeExp',
            size='pop', sizes=(25, 250), 
            hue='continent',alpha=0.7,
            col='year',col_wrap=4)
plt.xscale('log')

# %% [markdown]
# ### Same data with interactive plots

# %%
# Look at just one year
fig = px.scatter(tidy_df[tidy_df['year']==2007], x="gdpPercap", y="lifeExp",
           size="pop", color="continent", 
           log_x=True, size_max=55,
           hover_name='country')
fig.show()

# %%
# Create animation/slider instead of facetting
fig = px.scatter(tidy_df, x="gdpPercap", y="lifeExp",
           size="pop", color="continent", 
           hover_name="country",
           animation_frame='year',
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
fig.show()

# %%
# Combine animations with dropdowns
def update_plot(option):
    if option:
        x_scale = [100,100000]
    else:
        x_scale = [0,45000]
    fig = px.scatter(tidy_df, x="gdpPercap", y="lifeExp",
           size="pop", color="continent", 
           hover_name="country",
           animation_frame="year", 
           log_x=option, size_max=55, range_x=x_scale, range_y=[25,90])
    fig.show()

# Define dropdown options for x and y axes
scale_options = [True, False]

# Create dropdown widgets
scale_dropdown = widgets.Dropdown(options=scale_options, description='Log scale:')

# Create interactive plot using ipywidgets interact function
interact(update_plot, option=scale_dropdown);
# Out:
# interactive(children=(Dropdown(description='Log scale:', options=(True, False), value=True), Output()), _dom_c…

# %%
# Can also make animated bar charts
fig = px.bar(tidy_df, x="continent", y="pop", color="continent",
              animation_frame="year", hover_name = 'country',range_y=[0,4000000000])
fig.show()
