# %% [markdown]
# # Cleaning Data
# v.ekc
#
# Raw data is almost never ready to use. Today we clean the YouTube dataset from last week and learn to reshape wide/long data.... two skills you'll use constantly in the wild.
#
# | Section | Topic |
# |---------|-------|
# | 1 | Setup |
# | 2 | Cleaning the Data |
# | 3 | Reshaping Data |
# | 4 | 🔬 Activity: Pets DataFrame |
# | Appendix | Quick Reference |

# %% [markdown]
# ---
# ## 1. Setup

# %%
import numpy as np
import pandas as pd

# %%
# import the youtube data from last time
df = pd.read_csv('humboldt_youtube_2025.csv', dtype={'viewCount': 'object', 'likeCount':'object'})
df.head()

# %%
df.shape

# %% [markdown]
# ---
# ## 2. Cleaning the Data
#
# We'll work through four common cleaning steps: fixing column names, correcting data types, setting the index, and reordering.

# %% [markdown]
# ### References
#
# | Task | Code | Notes |
# |------|------|-------|
# | Rename specific columns | `df.rename(columns={'old':'new'})` | Returns new df unless `inplace=True` |
# | Rename all columns | `df.columns = [...]` | Replaces all names at once |
# | Drop column | `df.drop(columns='col', inplace=True)` | |
# | Remove constant columns | `df.loc[:, df.nunique() > 1]` | Keep only columns with >1 unique value |
# | Convert type | `df.astype({'col': int})` | |
# | Parse datetime | `pd.to_datetime(df['col'])` | Use `format=` for non-standard strings |
# | Set index | `df.set_index('col', inplace=True)` | |
# | Sort rows | `df.sort_values(by='col', ascending=False)` | |
# | Sort columns | `df.sort_index(axis=1)` | |

# %% [markdown]
# ### Column Names

# %%
# Check the column names
df.columns

# %%
# Inspect some questions
#   is published at and publish time the same?

sum(df.publishedAt != df.publishTime)

# %%
# the two columns above are identical
# Remember how to drop a column???
#    let's drop 'publishTime'

# %%
# Check for any columns with just one value
(df.nunique() == 1)

# %%
# Save some relevant data, then remove redundant columns
channel_id = df.channelId[0]
chanel_title = df.channelTitle[0]

# %%
df = df.loc[:,df.nunique() > 1]

# %%
df.head()

# %% [markdown]
# Our column names are in different formats — let's standardize them.

# %%
# OPTION 1 .rename method
df.rename(columns = {'videoId':'video_id',
                     'publishedAt':'published_at',
                     'viewCount':'view_count',
                     'likeCount':'like_count'}).head()

# %%
# does not update original (use inline=True)
df.head()

# %%
# OPTION 2: more general approach that would work for many columns
# Split column names by words
import re
split_by_words = [re.split('(?=[A-Z])',i) for i in df.columns]
split_by_words

# %%
# Insert an underscore between words
columns_with_underscores = ['_'.join(i).lower() for i in split_by_words]
columns_with_underscores

# %%
# Reassign column names
df.columns = columns_with_underscores

# %%
df.head()

# %% [markdown]
# ### Convert Datatypes

# %%
# Suppose we wanted to look at the relationship between view counts and like counts
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# plot a scatter with x=view_count, y=like_count

# %% [markdown]
# #### check

# %% [raw]
# sns.scatterplot(data = df, x='view_count',y='like_count')
# plt.show()
#
# sns.relplot(data=df,
#           x='view_count',
#           y='like_count')

# %% [markdown]
# ### We should have checked the dtypes!

# %%
# Something is funky. Check the data types
df.dtypes

# %%
# convert the data types
df = df.astype({'view_count':int, 'like_count':int})

# %%
# check data types again
df.dtypes

# %%
# plot again!

sns.
    
plt.show()

# %%
# What if we wanted to plot trend in view counts?
#    x = published_at
#    y = view_count

sns.
plt.show()

# %% [markdown]
# #### check

# %%
sns.relplot(data = df,
                x='published_at',
                y='view_count',
               kind='line')
plt.show()

# %% [markdown]
# ### change dtypes again!

# %%
# change dates to datetime data
df['published_at'] = pd.to_datetime(df.published_at)
df.head()

# %%
# Check dtypes again
df.dtypes

# %%
# plot again
plt.figure(figsize = (10,4))
sns.lineplot(data = df, x='published_at',y='view_count')
plt.show()

# %% [markdown]
# ### Pandas datetime types can be interpreted in multiple formats:
# ### `pd.to_datetime(date1, format = 'format string from below list')`
#
# | String | Format string |
# |--------|--------------|
# | `'April 5, 2025'` | `'%B %d, %Y'` |
# | `'Apr 5, 2025'` | `'%b %d, %Y'` |
# | `'4/5/25'` | `'%m/%d/%y'` |
# | `'5-4-25'` | `'%d-%m-%y'` |
# | `'4-5-2025'` | `'%m-%d-%Y'` |
#
# You use the code `pd.to_datetime(date1, format = 'format string from above list')`

# %% [markdown]
# #### Examples

# %%
date1 = 'April 5, 2025'
pd.to_datetime(date1, format = '%B %d, %Y')

# %%
date2 = 'Apr 5, 2025'
pd.to_datetime(date2, format = '%b %d, %Y')

# %%
date3 = '4/5/25'
pd.to_datetime(date3, format = '%m/%d/%y')

# %%
date4 = '5-4-25'
pd.to_datetime(date4, format = '%d-%m-%y')

# %%
date5 = '4-5-2025'
pd.to_datetime(date5, format = '%m-%d-%Y')

# %%
date6 = '4-05-2025'
pd.to_datetime(date5, format = '%m-%d-%Y')

# %% [markdown]
# Use [this reference](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior) for more info about datetime formats.

# %% [markdown]
# ### Reset the Index

# %%
# Reset the index for easy access by video id
df.set_index('video_id',inplace=True)
df.head()

# %%
# index by video id
video_id = "PoGnLtH1UHY"

......

# %%
# get the info on the video with the highest view count!

...
????...

# %%
#### check

# info on one video
video_id = "PoGnLtH1UHY"
df.loc[video_id]

# info on max watched video!
df.loc[df.view_count.idxmax()]

# %% [markdown]
# ### Reorder the Data

# %%
# reorder rows
df.sort_index(axis=0).head()


### Question: does this update the original????

# %%
# doesn't update original
df.head()

# %%
# reorder columns with axis=1
df.sort_index(axis=1).head()

# %%
# Place columns in your chosen order
df[['view_count','like_count','published_at','title']].head()

# %%
# sort the data 
df.sort_values(by='view_count').head()

# %%
# doesn't update original
df.head()

# %%
# do it inplace
df.sort_values(by = 'view_count',ascending=False, inplace=True)

# %%
df.head()

# %%
# sort by multiple values at once
df.sort_values(by = ['view_count','like_count'],ascending=[False,True], inplace=True)
df.head()

# %% [markdown]
# ---
# ## 3. Reshaping Data
#
# Data often arrives in the wrong shape for the analysis you want. Two transformations come up constantly: **wide → long** and **long → wide**. We'll build up each one step by step using weather data — then you'll practice on your own.

# %% [markdown]
# ### References
#
# | Direction | Function | When to use |
# |-----------|----------|--------------|
# | Wide → Long | `.melt(id_vars=, value_vars=)` | Each measurement → its own row |
# | Wide → Long | `.stack()` | Column names become a new index level |
# | Long → Wide | `.pivot(index=, columns=, values=)` | One value per cell — no aggregation |
# | Long → Wide | `.pivot_table(aggfunc=)` | Multiple values per cell — aggregate them |

# %% [markdown]
# ### Wide → Long
#
# The weather dataset has one column per variable. Let's collapse it so each row is a single measurement.

# %%
df_weather_wide = pd.read_csv('sample_weather.csv')
df_weather_wide = df_weather_wide.iloc[:,1:]
df_weather_wide

# %%
# METHOD 1

# transpose with more informative columns
date_index = df_weather_wide.set_index('date')
date_index

# %%
# Make a long Series
#   the result is a multi-indexed Series
#   level 0 index   |   level 1 index   |   value
#   dates, set index|   column names    |   cell values


long_df = date_index.stack()
long_df

# %%
# now we get rid of the double indexing
#    we reset the index

long_df = long_df.reset_index(name='value')
long_df

# and then we will rename that column from level_1 ---> variable
#long_df.rename(columns = {'level_1':'variable'},inplace=True)

# %%
# Method 1.5: a shortcut 
#   we pre-name the second index lol and then we don't have to rename it later

date_index.columns.name = 'variable'
date_index

# %%
# Now renaming isn't necessary
date_index.stack().reset_index(name = 'value')

# %% [markdown]
# ### The Two methods, `df.stack()` and `df.melt()`
#
# Both methods get you to the same place. Here's the full step-by-step for each:
#
# ---
#
# **`df.stack()`**
#
# | Step | Code | What it does |
# |------|------|--------------|
# | 1 | `df.set_index('date')` | Move the ID column into the index so only the *data* columns remain |
# | 2 | `.stack()` | Collapse all remaining columns into rows — column names become a new index level |
# | 3 | `.reset_index(name='value')` | Flatten the MultiIndex back to regular columns; `name=` sets the values column label |
# | 4 | `.rename(columns={'level_1': 'variable'})` | Give the auto-generated `level_1` column a meaningful name |
#
# > **Shortcut for step 4:** Set `df.columns.name = 'variable'` *before* stacking — then the level is already named and `.rename()` isn't needed.
#
# ---
#
# **`df.melt()`** *(the shortcut)*
#
# | Argument | Role | Example |
# |----------|------|---------|
# | `id_vars=` | Column(s) that stay as row identifiers — repeated for every melted variable | `'date'` |
# | `value_vars=` | Columns to collapse into rows — their names become the `variable` column | `['max_temp', 'min_temp', 'inches_of_rain']` |
#
# ```python
#
# date    max_temp  min_temp  inches_of_rain
# ↑           ↑        ↑            ↑
# id_vars  ←————————— value_vars ————————→    # the values of each cell become a new column called 'value'
# ```
#
#
# `df_weather_wide.melt(id_vars='date', value_vars=['max_temp', 'min_temp', 'inches_of_rain'])`
#
# ```python
# date  |  variable       |  value
# ——————————————————————————————————
# id_vars  |  col names      |  cell values
#          |  from           |  from
#          |  value_vars     |  value_vars
#
# ```
#
# > **When to use which:**
# > Use `.melt()` when you know your column names and want clean, readable code.
# > Use `.stack()` when you want to collapse *all* columns at once, or when working with a MultiIndex.

# %%
df_weather_wide.head()

# %%
# METHOD 2

long_df = df_weather_wide.melt(id_vars = 'date',value_vars = ['max_temp','min_temp','inches_of_rain'])
long_df

# %% [markdown]
# ---
# ### Try It 1: Wide → Long
#
# 1. Use `.melt()` on `df_weather_wide`, but only include `max_temp` and `min_temp` (leave out `inches_of_rain`). What changes in the output compared to the full melt above?
#
# 2. After melting, rename the `variable` column to `weather_metric` and `value` to `measurement` using `.rename()`. Practice chaining your cleaning steps — melt, then rename.
#
# **Make sure your changes stick!**

# %%
df_weather_wide.head()

# %%
# 1. Use .melt() — but only keep 'max_temp' and 'min_temp'
#     what is the id_vars?
#     what is the value_vars?

# %%
# 2. Rename the 'variable' and 'value' columns to something more descriptive
# Out:
#          date weather_metric  measurement
# 0  2024-01-01       max_temp           60
# 1  2024-01-02       max_temp           55
# 2  2024-01-03       max_temp           52
# 3  2022-01-04       max_temp           56
# 4  2024-01-01       min_temp           40
# 5  2024-01-02       min_temp           45
# 6  2024-01-03       min_temp           42
# 7  2022-01-04       min_temp           48

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Limiting `value_vars` is a quick way to melt only the columns you care about — great for dropping irrelevant variables before reshaping.*
#
# ```python
# # 1. melt with only 2 variables
# df_weather_wide.melt(id_vars='date', value_vars=['max_temp', 'min_temp'])
# # result has fewer rows — one per date per included variable
#
# # 2. rename after melting
# (
#     df_weather_wide
#     .melt(id_vars='date', value_vars=['max_temp', 'min_temp'])
#     .rename(columns={'variable': 'weather_metric', 'value': 'measurement'})
# )
# ```
#
# </details>

# %% [markdown]
# ### Long → Wide
#
# Now let's go the other direction. `.pivot()` works great when there's exactly **one value per (index, column) pair**. Howwever! real data often has duplicates. Let's see what happens.

# %%
# change long format back into wide format
long_df.pivot(index = 'date',columns = 'variable',values='value')

# %%
long_df = pd.read_csv('long_data.csv')
long_df = long_df.iloc[:,1:]
long_df.head()

# %%
# Pivot the data to get average sales by date and category
#   aggfunc = mean is default

long_df.pivot_table(index=['date'], columns=['category'], values=['sales'])

# %%
# Pivot the data to get TOTAL sales by date and category
wide_df = long_df.pivot_table(index=['date'], columns='category', values=['sales'], aggfunc=sum)
wide_df

# %%
# Pivot the data to get TOTAL sales by date, product, and category
long_df.pivot_table(index='date', columns=['category','product'], values=['sales'], aggfunc=sum)

# %%
wide_df

# %% [markdown]
# #### Hmmm not sure about this example, `df.reset_index().melt()`

# %%
# Go from wide to long

# name of the index is 'date'
#    wide_df.index

# name of the columns is multi-index: `category`
#    wide_df.columns

wide_df.reset_index().melt(id_vars=['date'], var_name=['type','category'])


# this works better with NORMAL index columns, no multi-index :(
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 9
#       1 # Go from wide to long
#       2
#       3 # name of the index is 'date'
#    (...)      6 # name of the columns is multi-index: `category`
#       7 #    wide_df.columns
# ----> 9 wide_df.reset_index().melt(id_vars=['date'], var_name=['type','category'])
#      12 # this works better with NORMAL index columns, no multi-index :(
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/data271/lib/python3.13/site-packages/pandas/core/frame.py:11697, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#   11567 def melt(
#   11568     self,
#   11569     id_vars=None,
#    (...)  11574     ignore_index: bool = True,
#   11575 ) -> DataFrame:
#   11576     """
#   11577     Unpivot DataFrame from wide to long format, optionally leaving identifiers set.
#   11578
# ...

# %% [markdown]
# #### example with `df.stack().reset_index()`

# %%
### let's just use stake because of the multi-index

long_df = (
    wide_df
    .stack()
)

long_df.head(10)


#long_df = (
#    wide_df
#    .stack()
#    .reset_index()
#)

#long_df.rename(columns={0: 'sales'})

#long_df.head()

# %% [markdown]
# ---
# ### 🔍 Identify It — Wide or Long?
#
# Before you write any code, look at each DataFrame below and answer two things:
# - Is it **wide** or **long** format?
# - What arguments would you need to convert it to the **other** format?
#
# Write your answers in the cells below each DataFrame. Then check the toggle when you're ready.

# %%
# DataFrame A
df_a = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Carol'],
    'math':    [90, 78, 95],
    'science': [85, 88, 91],
    'english': [92, 75, 88]
})
df_a

# %% [markdown]
# **DataFrame A**: fill in!
#
# 1. Is this **wide** or **long** format?
# 2. What `.melt()` arguments would you use to convert it to the other format?
#    - `id_vars =` ?
#    - `value_vars =` ?

# %%
# DataFrame B
df_b = pd.DataFrame({
    'city':    ['SF', 'SF', 'LA', 'LA'],
    'drink':   ['latte', 'mocha', 'latte', 'mocha'],
    'revenue': [400, 250, 350, 300]
})
df_b

# %% [markdown]
# **DataFrame B**: what is it??
#
# 1. Is this **wide** or **long** format?
# 2. - Can you use `.pivot()` or do you need `.pivot_table()`? *your answer*
# 3. Parameters
# - `index =` *?*
# - `columns =` *?*
# - `values =` *?*

# %%
# DataFrame C
df_c = pd.DataFrame({
    'city':  ['SF','SF','SF','LA','LA','LA'],
    'drink': ['latte','latte','mocha','latte','mocha','mocha'],
    'revenue': [400, 220, 250, 350, 300, 175]
})
df_c

# %% [markdown]
# **DataFrame C** — Look carefully before you answer 👀
#
# 1. Is this **wide** or **long** format?
# 2. Can you use `.pivot()` to go wide? *Check the data first.*
# 3. What arguments would you pass to `.pivot_table()` to get total revenue by city and drink?
# - `index =` *?*
# - `columns =` *?*
# - `values =` *?*
# - `aggfunc =` *?*
#
# > *Hint: scan the city/drink combos — do any repeat?*

# %% [markdown]
# <details>
# <summary>💡 Answers — click to peek</summary>
# <br>
#
# *The key question for long→wide is always: "is there exactly one value per (index, column) pair?" If yes, `.pivot()` works. If no, use `.pivot_table()` with an `aggfunc`.*
#
# **DataFrame A** is **wide** — each subject is its own column.
# ```python
# # melt() to go long
# df_a.melt(id_vars='student', value_vars=['math', 'science', 'english'])
# # id_vars='student'  →  the column that stays as the identifier
# # value_vars=[...]   →  the columns to collapse into rows
# ```
#
# **DataFrame B** is **long** — each row is one (city, drink) measurement, no duplicates.
# ```python
# # pivot() to go wide
# df_b.pivot(index='city', columns='drink', values='revenue')
# # index='city'    →  stays as the row label
# # columns='drink' →  unique values become new column names
# # values='revenue' →  fills in the cells
# ```
#
# **DataFrame C** is **long** — but SF/latte and LA/mocha each appear **twice**, so `.pivot()` would error.
# ```python
# # pivot_table() to go wide
# df_c.pivot_table(index='city', columns='drink', values='revenue', aggfunc=sum)
# # aggfunc=sum  →  adds the two SF/latte values (400 + 220 = 620)
# ```
#
# </details>

# %% [markdown]
# ---
# ### Try It 2: Long → Wide 😊
#
# 1. Use `pd.crosstab(index=long_df.date, columns=long_df.category)` to check for duplicates. What do you notice about the counts?
#
# 2. Try calling `.pivot()` on `long_df` with `index='date'`, `columns='category'`, `values='sales'`. What error do you get, and why?
#
# 3. Fix it by using `.pivot_table()` with `aggfunc=sum`. What does the resulting table represent?
#
# 4. Swap `aggfunc=sum` for `aggfunc=len`. What does *this* version tell you? How is it similar to `pd.crosstab()`?

# %%
# 1. Check for duplicate (date, category) combos using pd.crosstab()

# %%
# 2. Try .pivot() — what error do you get?
#    long_df.pivot(index='date', columns='category', values='sales')

# %%
# 3. Fix it with pivot_table() using aggfunc=sum

# %%
# 4. Now try aggfunc=len instead. What does this show?

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *`pd.crosstab()` is a quick way to spot duplicates before pivoting — if any cell shows > 1, use `.pivot_table()`.*
#
# ```python
# # 1. crosstab check
# pd.crosstab(index=long_df.date, columns=long_df.category)
#
# # 2. .pivot() raises ValueError — duplicates exist
# # long_df.pivot(index='date', columns='category', values='sales')
#
# # 3. pivot_table with sum
# long_df.pivot_table(index='date', columns='category', values='sales', aggfunc=sum)
#
# # 4. aggfunc=len shows counts — same as crosstab!
# long_df.pivot_table(index='date', columns='category', values='sales', aggfunc=len)
# ```
#
# </details>

# %% [markdown]
# ---
# ## 4. 🔬 Activity — Pets DataFrame
#
# Practice all three cleaning steps on a new dataset.

# %%
# Create a DataFrame with data cleaning and reshaping opportunities
data = {
    'Pet Name': ['Fluffy', 'Whiskers', 'Bubbles', 'Spike', 'Coco', 'Maybelle', 'Snowball'],
    'Date Adopted': ['10-01-2023','03-04-2024','01-10-2024','02-14-2024','11-22-2023','01-04-2024','12-25-2025'],
    'Animal Type': ['Cat', 'Cat', 'Fish', 'Dog', 'Fish', 'Dog', 'Cat'],
    'Pet Age': ['3', '2', '13', '5', '4', '3', '2'],
    'Color': ['White', 'Gray', 'Orange', 'White', 'White', 'Black', 'Black'],
    'Happiness Level': ['High', 'Medium', 'High', 'Low', 'High', 'High', 'Medium']
}
df_pets = pd.DataFrame(data)
df_pets

# %% [markdown]
# ---
# ### Try It 1: Clean the Pets DataFrame 😊
#
# 1. **Rename columns** to a consistent format (e.g., `snake_case` or `lowercase with spaces` — your choice).
#
# 2. **Fix datatypes** — any columns that should be converted? Think about `Pet Age` and `Date Adopted`.
#
# 3. **Reshape** — use `.pivot_table()` to find the average age by `Animal Type`. Then try melting the result back to long format.

# %%
# 1. Rename columns

# %%
# 2. Fix datatypes

# %%
# 3. pivot_table: average age by Animal Type

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *Many column naming conventions work — consistency is what matters.*
#
# ```python
# # 1. Rename
# df_pets = df_pets.rename(columns={
#     'Pet Name': 'pet_name',
#     'Date Adopted': 'date_adopted',
#     'Animal Type': 'animal_type',
#     'Pet Age': 'pet_age',
#     'Color': 'color',
#     'Happiness Level': 'happiness_level'
# })
#
# # 2. Fix types
# df_pets['pet_age'] = df_pets['pet_age'].astype(int)
# df_pets['date_adopted'] = pd.to_datetime(df_pets['date_adopted'], format='%m-%d-%Y')
#
# # 3. pivot_table
# df_pets.pivot_table(index='animal_type', values='pet_age', aggfunc='mean')
# ```
#
# </details>

# %% [markdown]
# ---
# ## Appendix — Cleaning & Reshaping Quick Reference
#
# ### Cleaning
# ```python
# df.rename(columns={'old':'new'}, inplace=True)       # rename specific columns
# df.columns = ['col1', 'col2', ...]                   # rename all columns
# df.drop(columns='col', inplace=True)                 # drop a column
# df = df.loc[:, df.nunique() > 1]                     # drop constant columns
# df = df.astype({'col': int})                         # convert type
# df['col'] = pd.to_datetime(df['col'])                # parse datetime
# df.set_index('col', inplace=True)                    # set index
# df.sort_values(by='col', ascending=False, inplace=True)  # sort rows
# ```
#
# ### Reshaping
# ```python
# # Wide → Long
# df.melt(id_vars='id_col', value_vars=['a','b'])       # melt
# df.set_index('id').stack().reset_index(name='value')  # stack
#
# # Long → Wide
# df.pivot(index='id', columns='var', values='val')     # pivot (no aggregation)
# df.pivot_table(index='id', columns='var',             # pivot_table (aggregates)
#                values='val', aggfunc=sum)
# ```
