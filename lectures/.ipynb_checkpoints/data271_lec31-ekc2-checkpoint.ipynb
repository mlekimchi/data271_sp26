# %% [markdown]
# # Web Scraping
# v.ekc
#
# Not all data comes with an API. Today we learn to fetch web pages programmatically and parse their HTML structure to extract tables and content using BeautifulSoup.
#
# | Section | Topic |
# |---------|-------|
# | 1 | Setup |
# | 2 | Scraping a Basic Webpage |
# | 3 | Scraping a Complex Page......Cal Poly Humboldt |
# | 4 | Building a DataFrame from Scraped Tables |
# | 5 | 🔬 Activity: Humboldt Geographic Data |
# | Appendix | Quick Reference |

# %% [markdown]
# ---
# ## 1. Setup

# %%
import numpy as np
import pandas as pd

# %%
# Whenever you want to scrape a website without an API
import io
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ---
# ## 2. Scraping a Basic Webpage
#
# We'll start with a very simple page to learn the basics of HTML parsing. BeautifulSoup documentation [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# Let's look at [this](https://web.ics.purdue.edu/~gchopra/class/public/pages/webdesign/05_simple.html) very simple webpage.

# %% [markdown]
# ###
#
# | Code | What it does |
# |------|--------------|
# | `requests.get(url)` | Fetch a webpage |
# | `site.status_code` | `200` = success |
# | `BeautifulSoup(site.text)` | Parse raw HTML |
# | `soup.find('tag')` | First matching element |
# | `soup.find_all('tag')` | All matching elements (returns list) |
# | `element['attr']` | Get an attribute (e.g., `element['href']`) |
# | `element.text` | Get the text content of an element |

# %% [markdown]
# We're starting with an intentionally bare-bones webpage without JavaScript or dynamic content. This lets us focus on the HTML parsing mechanics before dealing with a real site's complexity. Once these basics click, the same tools work on any page.

# %%
# Get the content of a website
site = requests.get('https://web.ics.purdue.edu/~gchopra/class/public/pages/webdesign/05_simple.html')

# %%
# What did we just get?
type(site)
# Out:
# requests.models.Response

# %%
# Check the status
site.status_code
# Out:
# 200

# %%
# With APIs, the output was typically JSON, but not regular webpages
site.json() # error!
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/data271/lib/python3.13/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/data271/lib/python3.13/json/__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/data271/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/data271/lib/python3.13/json/decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 2
#       1 # With APIs, the output was typically JSON, but not regular webpages
# ----> 2 site.json() # error!
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/data271/lib/python3.13/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# Web APIs return structured JSON. Regular webpages return **raw HTML** which appears as a long string of tags, attributes, and content all tangled together. `.text` gives us that raw string. The next step is teaching Python to make sense of it.

# %%
# inspect the contents with text
site.text
# messy!

# %% [markdown]
# That raw HTML is technically readable but practically unusable and you'd have to write your own string parsing to find anything. **BeautifulSoup** parses that string into a tree of objects you can navigate with simple method calls. Think of it as turning a wall of text into a searchable document.

# %%
# Let's ****beautify**** this and make it easier to parse
soup = BeautifulSoup(site.text)

# %%
# What does our soup look like?
soup
# Out:
# <html>
# <head>
# <title>A very simple webpage</title>
# <basefont size="4"/>
# </head>
# <body bgcolor="FFFFFF">
# <h1>A very simple webpage. This is an "h1" level header.</h1>
# <h2>This is a level h2 header.</h2>
# <h6>This is a level h6 header.  Pretty small!</h6>
# <p>This is a standard paragraph.</p>
# <p align="center">Now I've aligned it in the center of the screen.</p>
# <p align="right">Now aligned to the right</p>
# <p><b>Bold text</b></p>
# <p><strong>Strongly emphasized text</strong>  Can you tell the difference vs. bold?</p>
# <p><i>Italics</i></p>
# <p><em>Emphasized text</em>  Just like Italics!</p>
# <p>Here is a pretty picture: <img alt="Pretty Picture" src="example/prettypicture.jpg"/></p>
# <p>Same thing, aligned differently to the paragraph: <img align="top" alt="Pretty Picture" src="example/prettypicture.jpg"/></p>
# <hr/>
# <h2>How about a nice ordered list!</h2>
# <ol>
# <li>This little piggy went to market
#   </li><li>This little piggy went to SB228 class
#   </li><li>This little piggy went to an expensive restaurant in Downtown Palo Alto
#   </li><li>This little piggy ate too much at Indian Buffet.
#   </li><li>This little piggy got lost
# </li></ol>
# <h2>Unordered list</h2>
# <ul>
# <li>First element
#   </li><li>Second element
#   </li><li>Third element
# </li></ul>
# <hr/>
# <h2>Nested Lists!</h2>
# <ul>
# <li>Things to to today:
#     <ol>
# <li>Walk the dog
#       </li><li>Feed the cat
#       </li><li>Mow the lawn
#     </li></ol>
# </li><li>Things to do tomorrow:
#     <ol>
# <li>Lunch with mom
#       </li><li>Feed the hamster
#       </li><li>Clean kitchen
#     </li></ol>
# </li></ul>
# <p>And finally, how about some <a href="http://www.yahoo.com/">Links?</a></p>
# <p>Or let's just link to <a href="../../index.html">another page on this server</a></p>
# <p>Remember, you can view the HTMl code from this or any other page by using the "View Page Source" command of your browser.</p>
# </body>
# </html>

# %%
soup.prettify()
# Out:
# '<html>\n <head>\n  <title>\n   A very simple webpage\n  </title>\n  <basefont size="4"/>\n </head>\n <body bgcolor="FFFFFF">\n  <h1>\n   A very simple webpage. This is an "h1" level header.\n  </h1>\n  <h2>\n   This is a level h2 header.\n  </h2>\n  <h6>\n   This is a level h6 header.  Pretty small!\n  </h6>\n  <p>\n   This is a standard paragraph.\n  </p>\n  <p align="center">\n   Now I\'ve aligned it in the center of the screen.\n  </p>\n  <p align="right">\n   Now aligned to the right\n  </p>\n  <p>\n   <b>\n    Bold text\n   </b>\n  </p>\n  <p>\n   <strong>\n    Strongly emphasized text\n   </strong>\n   Can you tell the difference vs. bold?\n  </p>\n  <p>\n   <i>\n    Italics\n   </i>\n  </p>\n  <p>\n   <em>\n    Emphasized text\n   </em>\n   Just like Italics!\n  </p>\n  <p>\n   Here is a pretty picture:\n   <img alt="Pretty Picture" src="example/prettypicture.jpg"/>\n  </p>\n  <p>\n   Same thing, aligned differently to the paragraph:\n   <img align="top" alt="Pretty Picture" src="example/prettypicture.jpg"/>\n  </p>\n  <hr/>\n  <h2>\n   How about a nice ordered list!\n  </h2>\n  <ol>\n   <li>\n    This little piggy went to market\n   </li>\n   <li>\n    This little piggy went to SB228 class\n   </li>\n   <li>\n    This little piggy went to an expensive restaurant in Downtown Palo Alto\n   </li>\n   <li>\n    This little piggy ate too much at Indian Buffet.\n   </li>\n   <li>\n    This little piggy got lost\n   </li>\n  </ol>\n  <h2>\n   Unordered list\n  </h2>\n  <ul>\n   <li>\n    First element\n   </li>\n   <li>\n    Second element\n   </li>\n   <li>\n    Third element\n   </li>\n  </ul>\n  <hr/>\n  <h2>\n   Nested Lists!\n  </h2>\n  <ul>\n   <li>\n    Things to to today:\n    <ol>\n     <li>\n      Walk the dog\n     </li>\n     <li>\n      Feed the cat\n     </li>\n     <li>\n      Mow the lawn\n     </li>\n    </ol>\n   </li>\n   <li>\n    Things to do tomorrow:\n    <ol>\n     <li>\n      Lunch with mom\n     </li>\n     <li>\n      Feed the hamster\n     </li>\n     <li>\n      Clean kitchen\n     </li>\n    </ol>\n   </li>\n  </ul>\n  <p>\n   And finally, how about some\n   <a href="http://www.yahoo.com/">\n    Links?\n   </a>\n  </p>\n  <p>\n   Or let\'s just link to\n   <a href="../../index.html">\n    another page on this server\n   </a>\n  </p>\n  <p>\n   Remember, you can view the HTMl code from this or any other page by using the "View Page Source" command of your browser.\n  </p>\n </body>\n</html>\n'

# %%
# Make it even prettier
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A very simple webpage
#   </title>
#   <basefont size="4"/>
#  </head>
#  <body bgcolor="FFFFFF">
#   <h1>
#    A very simple webpage. This is an "h1" level header.
#   </h1>
#   <h2>
#    This is a level h2 header.
#   </h2>
#   <h6>
#    This is a level h6 header.  Pretty small!
#   </h6>
#   <p>
#    This is a standard paragraph.
#   </p>
#   <p align="center">
#    Now I've aligned it in the center of the screen.
#   </p>
#   <p align="right">
#    Now aligned to the right
#   </p>
#   <p>
#    <b>
#     Bold text
#    </b>
#   </p>
#   <p>
#    <strong>
#     Strongly emphasized text
#    </strong>
#    Can you tell the difference vs. bold?
#   </p>
#   <p>
#    <i>
#     Italics
#    </i>
#   </p>
#   <p>
#    <em>
#     Emphasized text
#    </em>
#    Just like Italics!
#   </p>
#   <p>
#    Here is a pretty picture:
#    <img alt="Pretty Picture" src="example/prettypicture.jpg"/>
#   </p>
#   <p>
#    Same thing, aligned differently to the paragraph:
#    <img align="top" alt="Pretty Picture" src="example/prettypicture.jpg"/>
#   </p>
#   <hr/>
#   <h2>
#    How about a nice ordered list!
#   </h2>
#   <ol>
#    <li>
#     This little piggy went to market
#    </li>
#    <li>
#     This little piggy went to SB228 class
#    </li>
#    <li>
#     This little piggy went to an expensive restaurant in Downtown Palo Alto
#    </li>
#    <li>
#     This little piggy ate too much at Indian Buffet.
#    </li>
#    <li>
#     This little piggy got lost
#    </li>
#   </ol>
#   <h2>
#    Unordered list
#   </h2>
#   <ul>
#    <li>
#     First element
#    </li>
#    <li>
#     Second element
#    </li>
#    <li>
#     Third element
#    </li>
#   </ul>
#   <hr/>
#   <h2>
#    Nested Lists!
#   </h2>
#   <ul>
#    <li>
#     Things to to today:
#     <ol>
#      <li>
#       Walk the dog
#      </li>
#      <li>
#       Feed the cat
#      </li>
#      <li>
#       Mow the lawn
#      </li>
#     </ol>
#    </li>
#    <li>
#     Things to do tomorrow:
#     <ol>
#      <li>
#       Lunch with mom
#      </li>
#      <li>
#       Feed the hamster
#      </li>
#      <li>
#       Clean kitchen
#      </li>
#     </ol>
#    </li>
#   </ul>
#   <p>
#    And finally, how about some
#    <a href="http://www.yahoo.com/">
#     Links?
#    </a>
#   </p>
#   <p>
#    Or let's just link to
#    <a href="../../index.html">
#     another page on this server
#    </a>
#   </p>
#   <p>
#    Remember, you can view the HTMl code from this or any other page by using the "View Page Source" command of your browser.
#   </p>
#  </body>
# </html>

# %% [markdown]
# Now we can start pulling out specific pieces. Two key methods:
# - **`soup.find('tag')`** — returns the *first* matching element, or `None` if not found
# - **`soup.find_all('tag')`** — returns a *list* of all matching elements (empty list if none)
#
# HTML elements also carry **attributes** (like `href` on links) and **text content** (the visible words on screen). We access these separately.

# %% [markdown]
# ### Parse the html

# %%
# Find a level 1 header
soup.find('h1')

# %%
# Find a level 2 header
soup.find('h2')

# %%
# Find all the level 2 headers
soup.find_all('h2')

# %%
# Find all the level 3 headers
soup.find_all('h3')
# There were none.

# %%
# Find all the paragraphs
soup.find_all('p')

# %%
# Find all the hyperlinks
soup.find_all('a')

# %% [markdown]
# An `<a>` tag has two useful pieces: the **URL** (stored in the `href` attribute) and the **display text** (what you see on screen). These are accessed differently:
# - `element['href']` — gets an attribute value, like a dictionary key
# - `element.text` — gets all the text nested inside the tag

# %%
# Get the links
soup.find('a')['href']

# %%
# Get the text for the hyperlink
soup.find('a').text

# %% [markdown]
# HTML has two list types: **`<ol>`** (ordered / numbered) and **`<ul>`** (unordered / bulleted). Both contain **`<li>`** items. `find_all('li')` returns items from both — use `find_all('ol')` or `find_all('ul')` when you need to distinguish them.

# %%
# Get all the list items
soup.find_all('li')

# %%
# Specifically get the ordered lists
soup.find_all('ol')

# %%
# Specifically get the unordered lists
soup.find_all('ul')

# %% [markdown]
# ---
# ### Try It 1: Parse the Simple Page 😊
#
# Use the `soup` object from the simple Purdue page above.
#
# 1. Use `find_all('p')` to get all paragraph elements. How many are there? Extract the text from each one into a Python list using a list comprehension.
#
# 2. Find all hyperlinks (`<a>` tags). For each one, print both the display text and the URL it points to.
#
# 3. The page has both ordered and unordered lists. How many total `<li>` items are there? Can you tell which items belong to the `<ol>` vs the `<ul>`?

# %%
# 1. All paragraphs → list of text

# %%
# 2. All links → print text + href

# %%
# 3. Count li items; split by ol vs ul

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# ```python
# # 1.
# paragraphs = [paragraphs.text for paragraphs in soup.find_all('p')]
# print(len(paragraphs), paragraphs)
#
# # 2.
# for a in soup.find_all('a'):
#     print(a.text, '"', a['href'])
#
# # 3.
# print('Total li:', len(soup.find_all('li')))
# for ol in soup.find_all('ol'):
#     print('ordered list items:', [li.text for li in ol.find_all('li')])
# for ul in soup.find_all('ul'):
#     print('unordered list items:', [li.text for li in ul.find_all('li')])
# ```
#
# </details>

# %% [markdown]
# ---
# ## 3. Scraping a Complex Page: Cal Poly Humboldt
#
# Let's check out [this](https://www.humboldt.edu/irar/fall-semester-fast-facts) Cal Poly Humboldt website and extract a specific data table.

# %% [markdown]
# ### 📋 Board Reference
#
# | Code | What it does |
# |------|--------------|
# | `soup.find_all('tag', class_='cls')` | Filter by CSS class |
# | `soup.select('tag.cls')` | CSS selector shorthand |
# | `soup.find_all('table')` | All HTML tables |
# | `table.find_all('tr')` | All rows in a table |
# | `row.find_all('td')` | All cells in a row |

# %%
# Get the data
cph_stats = requests.get('https://www.humboldt.edu/irar/fall-semester-fast-facts')
cph_stats.status_code
# Out:
# 200

# %%
# Beautify the data
cph_soup = BeautifulSoup(cph_stats.text, 'html.parser')

# %%
# Pretty!
print(cph_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#">
#  <head>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PJJ2KH2');
#   </script>
#   <meta charset="utf-8"/>
#   <link href="https://www.humboldt.edu/irar/fall-semester-fast-facts" rel="canonical"/>
#   <link href="," rel="image_src"/>
#   <meta content="Cal Poly Humboldt" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://www.humboldt.edu/irar/fall-semester-fast-facts" property="og:url"/>
#   <meta content="Fall Semester Fast Facts | Cal Poly Humboldt" property="og:title"/>
#   <meta content="" property="og:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@humboldtcalpoly" name="twitter:site"/>
#   <meta content="Fall Semester Fast Facts | Cal Poly Humboldt" name="twitter:title"/>
#   <meta content="@humboldtcalpoly" name="twitter:creator"/>
#   <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/sites/default/files/favicon_0_0.png" rel="icon" type="image/png"/>
#   <title>
#    Fall Semester Fast Facts | Cal Poly Humboldt
#   </title>
#   <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
#   <link href="/sites/default/files/css/css_HJg_2pAqpyBfhefxQq1cQ4_f1mQcRZUSV5cbDyyIhNY.css?delta=0&amp;language=en&amp;theme=humboldt&amp;include=eJxtUNEKAyEM-yF3fpJU7VRWrdi62_39ZLDdPQxKKAkJaT2Eh1Ne060_d1cCNxN4oI1jdqANpnLg2gkVTZ7VM0W1ETsMrdjULZinkIg90E30oNLSyTeO6O6Er-IJXYd0CVtRkAb07JbnsUD0n7gfUvYjmR8j344ns83Wp18JGaMRhBGyu15gNWPFrZZW6jIGESOHKNb1BEHzLLiL_eBWOU7CNwq9dR0" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_xL0A1ocmPMoialFLPbf1e8PoP9muqXHgAS98Eeja8XY.css?delta=1&amp;language=en&amp;theme=humboldt&amp;include=eJxtUNEKAyEM-yF3fpJU7VRWrdi62_39ZLDdPQxKKAkJaT2Eh1Ne060_d1cCNxN4oI1jdqANpnLg2gkVTZ7VM0W1ETsMrdjULZinkIg90E30oNLSyTeO6O6Er-IJXYd0CVtRkAb07JbnsUD0n7gfUvYjmR8j344ns83Wp18JGaMRhBGyu15gNWPFrZZW6jIGESOHKNb1BEHzLLiL_eBWOU7CNwq9dR0" media="all" rel="stylesheet"/>
#   <link href="https://use.typekit.net/tvu2yrv.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_IR1Qm2WqQJASPHX5z1LbDsISrudl-lhunuVMiTiezxE.css?delta=3&amp;language=en&amp;theme=humboldt&amp;include=eJxtUNEKAyEM-yF3fpJU7VRWrdi62_39ZLDdPQxKKAkJaT2Eh1Ne060_d1cCNxN4oI1jdqANpnLg2gkVTZ7VM0W1ETsMrdjULZinkIg90E30oNLSyTeO6O6Er-IJXYd0CVtRkAb07JbnsUD0n7gfUvYjmR8j344ns83Wp18JGaMRhBGyu15gNWPFrZZW6jIGESOHKNb1BEHzLLiL_eBWOU7CNwq9dR0" media="all" rel="stylesheet"/>
#  </head>
#  <body class="page-node-26280 logged-out path-node page-node-type-flexible-page no-sidebar has-secondary-menu no-transition irar">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJJ2KH2" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <nav id="skip">
#    <a class="focusable skip-link" href="#main" rel="nofollow">
#     Skip to main content
#    </a>
#    <a class="focusable skip-link" href="#" id="nav-skip" rel="nofollow">
#     Primary Navigation
#    </a>
#    <a class="focusable skip-link" href="#footer" rel="nofollow">
#     Site Footer
#    </a>
#   </nav>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <header class="header">
#     <div class="container-fluid">
#      <div class="logo">
#       <a href="/">
#        <img alt="Cal Poly Humboldt" id="logo" src="/themes/humboldt/images/Logo.svg"/>
#        <img alt="Cal Poly Humboldt H Logo" id="logoH" src="/themes/humboldt/images/logoH.svg"/>
#       </a>
#      </div>
#     </div>
#     <div class="d-flex nav-switches justify-content-end resource-focus">
#      <div class="drop-menu d-none d-lg-block resource-focus" id="drop-menu">
#       <a class="drop-menu-link" data-target="#student-resources" data-toggle="modal" href="#student-resources" id="drop-menu-trigger" role="button">
#        <span class="trigger">
#         Quick Links
#         <span class="icon ion-ios-arrow-thin-down">
#         </span>
#        </span>
#       </a>
#      </div>
#      <a aria-expanded="false" class="search-switch nav-switch d-flex flex-column" data-target="#site-search" data-toggle="modal" href="#site-search" role="button">
#       <div class="button-inner">
#        <span class="icon ion-ios-search-strong">
#        </span>
#        <span class="switch-label">
#         Search
#        </span>
#       </div>
#      </a>
#      <a aria-label="open menu" class="hamburger-wrap nav-switch d-flex flex-column" href="#" id="hamburger">
#       <div class="button-inner">
#        <div class="hamburger hamburger--collapse" type="button">
#         <span class="hamburger-box">
#          <span class="hamburger-inner">
#          </span>
#         </span>
#        </div>
#        <span class="switch-label open-label">
#         Menu
#        </span>
#        <span class="switch-label close-label">
#         Close
#        </span>
#       </div>
#      </a>
#     </div>
#     <div class="department-menu-wrapper">
#      <div class="menu-header d-lg-none">
#       <a class="home-touch" href="/irar">
#        <span class="icon ion-ios-home">
#        </span>
#        IRAR
#       </a>
#       <a aria-controls="department-menu" aria-expanded="false" class="department-menu collapsed" data-toggle="collapse" href="#department-menu" role="button">
#       </a>
#      </div>
#      <div class="d-lg-flex container-fluid align-items-center collapse" id="department-menu">
#       <div class="menu-name d-none d-lg-block">
#        <a href="/irar">
#         <span class="icon ion-ios-home">
#         </span>
#         IRAR
#        </a>
#       </div>
#       <div class="level-1 d-block d-lg-inline-flex w-100">
#        <div class="d-lg-flex top-link align-items-center">
#         <a class="top-level" href="/irar">
#          Home
#         </a>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <span aria-controls="dropdown-menu_link_contentba5c968f-d726-41b6-b910-a7a96e7ee175" aria-expanded="false" aria-label="Expand Got Data? menu" class="menu-expand" data-target="#dropdown-menu_link_contentba5c968f-d726-41b6-b910-a7a96e7ee175" data-toggle="collapse">
#          Got Data?
#         </span>
#         <button aria-controls="dropdown-menu_link_contentba5c968f-d726-41b6-b910-a7a96e7ee175" aria-expanded="false" aria-label="Expand Got Data? menu" class="circle" data-target="#dropdown-menu_link_contentba5c968f-d726-41b6-b910-a7a96e7ee175" data-toggle="collapse" type="button">
#          <div class="button-inner">
#           <span class="d-none">
#            Expand	Got Data?	Menu
#           </span>
#          </div>
#         </button>
#         <div class="menu-panel collapse" data-parent="#department-menu" id="dropdown-menu_link_contentba5c968f-d726-41b6-b910-a7a96e7ee175">
#          <div class="panel-inner d-lg-flex container-fluid">
#           <div class="menu-info flex-grow-2">
#            <div class="panel-title d-none d-lg-block">
#             Got Data?
#            </div>
#           </div>
#           <div class="panel-links w-100">
#            <div class="row">
#             <div class="col-lg-3">
#              <a href="/irar/got-data/got-data">
#               Got Data?
#              </a>
#              <a href="/irar/got-data/admissions-data">
#               Admissions Data
#              </a>
#              <a href="/irar/enrollment-data">
#               Enrollment Data
#              </a>
#             </div>
#             <div class="col-lg-3">
#              <a href="/irar/got-data/course-class">
#               Courses and Classes
#              </a>
#              <a href="/irar/got-data/grad-reten">
#               Graduation and Retention
#              </a>
#              <a href="/irar/got-data/DEI">
#               Diversity, Equity, and Inclusion
#              </a>
#             </div>
#             <div class="col-lg-3">
#              <a href="/irar/got-data/HUMIS">
#               HUMIS Reports
#              </a>
#              <a href="/irar/got-data/dod">
#               Data On Demand
#              </a>
#              <a href="/irar/got-data/data-glossary">
#               Humboldt IRAR Data Glossary
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <a class="top-level" href="/irar/january-data-viz">
#          Data Viz
#         </a>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <a class="top-level" href="/irar/infographics">
#          Infographics
#         </a>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <span aria-controls="dropdown-menu_link_content4d2f0078-c89b-49ed-8dc1-988d7ffbe660" aria-expanded="false" aria-label="Expand Institutional Research menu" class="menu-expand" data-target="#dropdown-menu_link_content4d2f0078-c89b-49ed-8dc1-988d7ffbe660" data-toggle="collapse">
#          Institutional Research
#         </span>
#         <button aria-controls="dropdown-menu_link_content4d2f0078-c89b-49ed-8dc1-988d7ffbe660" aria-expanded="false" aria-label="Expand Institutional Research menu" class="circle" data-target="#dropdown-menu_link_content4d2f0078-c89b-49ed-8dc1-988d7ffbe660" data-toggle="collapse" type="button">
#          <div class="button-inner">
#           <span class="d-none">
#            Expand	Institutional Research	Menu
#           </span>
#          </div>
#         </button>
#         <div class="menu-panel collapse" data-parent="#department-menu" id="dropdown-menu_link_content4d2f0078-c89b-49ed-8dc1-988d7ffbe660">
#          <div class="panel-inner d-lg-flex container-fluid">
#           <div class="menu-info flex-grow-2">
#            <div class="panel-title d-none d-lg-block">
#             Institutional Research
#            </div>
#           </div>
#           <div class="panel-links w-100">
#            <div class="row">
#             <div class="col-lg-3">
#              <a href="/irar/institutional-research/survey-policies-and-procedures">
#               Campus Survey Policies and Procedures
#              </a>
#              <a href="/irar/institutional-research/research">
#               Institutional Research
#              </a>
#              <a href="/irar/institutional-research/IR-presents">
#               Presentations
#              </a>
#             </div>
#             <div class="col-lg-3">
#              <a href="/irar/institutional-research/campus-research-analysis">
#               Campus Research and Analysis
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <a class="top-level" href="https://academicprograms.humboldt.edu/content/learning-assessment">
#          Assessment and Program Review
#         </a>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <a class="top-level" href="/irar/welcome-data-management-page">
#          Data Management
#         </a>
#        </div>
#        <div class="d-lg-flex top-link align-items-center">
#         <span aria-controls="dropdown-menu_link_content6130e374-8686-4ee0-9a08-6c2bfdee8e38" aria-expanded="false" aria-label="Expand About Us menu" class="menu-expand" data-target="#dropdown-menu_link_content6130e374-8686-4ee0-9a08-6c2bfdee8e38" data-toggle="collapse">
#          About Us
#         </span>
#         <button aria-controls="dropdown-menu_link_content6130e374-8686-4ee0-9a08-6c2bfdee8e38" aria-expanded="false" aria-label="Expand About Us menu" class="circle" data-target="#dropdown-menu_link_content6130e374-8686-4ee0-9a08-6c2bfdee8e38" data-toggle="collapse" type="button">
#          <div class="button-inner">
#           <span class="d-none">
#            Expand	About Us	Menu
#           </span>
#          </div>
#         </button>
#         <div class="menu-panel collapse" data-parent="#department-menu" id="dropdown-menu_link_content6130e374-8686-4ee0-9a08-6c2bfdee8e38">
#          <div class="panel-inner d-lg-flex container-fluid">
#           <div class="menu-info flex-grow-2">
#            <div class="panel-title d-none d-lg-block">
#             About Us
#            </div>
#           </div>
#           <div class="panel-links w-100">
#            <div class="row">
#             <div class="col-lg-3">
#              <a href="/irar/about-us/meet-team">
#               Meet the Team
#              </a>
#              <a href="/irar/about-us/purpose-vision">
#               Purpose &amp; Vision
#              </a>
#              <a href="/irar/about-us/outcomes">
#               Office Outcomes and Plans
#              </a>
#             </div>
#             <div class="col-lg-3">
#              <a href="/irar/about-us/partners">
#               Strategic Partner List
#              </a>
#              <a href="/irar/about-us/office-contact">
#               Office Contact
#              </a>
#              <a href="/irar/about-us/points-pride">
#               Points of Pride
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="resource-focus" id="resource-panels">
#     <div aria-hidden="true" aria-labelledby="Quick Links Modal" class="modal fade resource-wrap" data-parent="#student-resources" id="student-resources" tabindex="-1">
#      <div class="modal-dialog modal-dialog-centered">
#       <div class="modal-content inner d-flex flex-column modal-content flex-grow-1">
#        <h2>
#         Quick Links
#        </h2>
#        <div class="resource-footer">
#         <nav aria-labelledby="block-studentresourcesfooter-menu" id="block-studentresourcesfooter" role="navigation">
#          <h3 class="visually-hidden" id="block-studentresourcesfooter-menu">
#           Campus Resources
#          </h3>
#          <ul region="student_resources_footer">
#           <li>
#            <a href="https://my.humboldt.edu" target="_blank">
#             myHumboldt
#            </a>
#           </li>
#           <li>
#            <a href="https://commerce.cashnet.com/HUMBOLDTACH">
#             Make a Payment
#            </a>
#           </li>
#           <li>
#            <a href="https://extended.humboldt.edu/">
#             eLearning
#            </a>
#           </li>
#           <li>
#            <a href="http://myhousing.humboldt.edu/">
#             myHousing
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#        <div class="d-lg-flex align-items-center a-z-index">
#         <div>
#          A-Z Index:
#         </div>
#         <ul class="d-flex flex-wrap justify-content-center">
#          <li>
#           <a href="/directories/site-index">
#            A
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/b">
#            B
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/c">
#            C
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/d">
#            D
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/e">
#            E
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/f">
#            F
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/g">
#            G
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/h">
#            H
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/i">
#            I
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/j">
#            J
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/k">
#            K
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/l">
#            L
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/m">
#            M
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/n">
#            N
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/o">
#            O
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/p">
#            P
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/q">
#            Q
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/r">
#            R
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/s">
#            S
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/t">
#            T
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/u">
#            U
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/v">
#            V
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/w">
#            W
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/x">
#            X
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/y">
#            Y
#           </a>
#          </li>
#          <li>
#           <a href="/site-index/z">
#            Z
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="resource-limit">
#         <nav aria-labelledby="block-currentstudentresources-menu" id="block-currentstudentresources" role="navigation">
#          <h2 class="visually-hidden" id="block-currentstudentresources-menu">
#           Quicklinks
#          </h2>
#          <div class="row d-flex">
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Directories
#            </h4>
#            <ul>
#             <li>
#              <a data-drupal-link-system-path="node/14644" href="/academics/colleges/departments">
#               Academic Departments
#              </a>
#             </li>
#             <li>
#              <a href="https://its.humboldt.edu/directory">
#               Faculty &amp; Staff Directory
#              </a>
#             </li>
#             <li>
#              <a href="https://its.humboldt.edu/student-directory">
#               Student Directory
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Campus Info
#            </h4>
#            <ul>
#             <li>
#              <a data-drupal-link-system-path="node/14630" href="/admission-aid/visit/directions">
#               Campus Maps
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/14654" href="/about/polytechnic/branding-initiative">
#               Humboldt Brand
#              </a>
#             </li>
#             <li>
#              <a href="https://president.humboldt.edu/ombuds/">
#               Ombuds Services
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/24353" href="/transportation-parking">
#               Parking
#              </a>
#             </li>
#             <li>
#              <a href="https://police.humboldt.edu/">
#               Police
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Events &amp; Activities
#            </h4>
#            <ul>
#             <li>
#              <a href="/events">
#               Calendars &amp; Events
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/25058" href="/campus-recreation">
#               Campus Recreation
#              </a>
#             </li>
#             <li>
#              <a href="https://tickets.humboldt.edu/calpolyhumboldt-presents">
#               Cal Poly Humboldt Presents
#              </a>
#             </li>
#             <li>
#              <a href="https://ces.humboldt.edu/community-planning">
#               Facility Rental
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Faculty &amp; Staff
#            </h4>
#            <ul>
#             <li>
#              <a data-drupal-link-system-path="node/21778" href="/academic-personnel-services">
#               Academic Personnel Serv.
#              </a>
#             </li>
#             <li>
#              <a href="https://dineoncampus.com/calpolyhumboldt/faculty--staff-meal-plans">
#               Faculty &amp; Staff Dining
#              </a>
#             </li>
#             <li>
#              <a href="https://kra.humboldt.edu/content/healthy-u">
#               Healthy-U Program
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/29030" href="/hr">
#               Human Resources
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Technology Help
#            </h4>
#            <ul>
#             <li>
#              <a href="https://idm-prov.humboldt.edu/identity/self-service/hsu/caslogin.jsp">
#               Account Settings
#              </a>
#             </li>
#             <li>
#              <a href="https://its.humboldt.edu/internet-wifi/eduroam">
#               Internet &amp; Wifi
#              </a>
#             </li>
#             <li>
#              <a href="https://idm-prov.humboldt.edu/identity/self-service/hsu/smsreset.jsf">
#               Reset Your Password
#              </a>
#             </li>
#             <li>
#              <a href="https://its.humboldt.edu/help/top-help-desk-issues">
#               Technology Assistance
#              </a>
#             </li>
#             <li>
#              <a href="https://its.humboldt.edu/">
#               ITS Support Request
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Student Services
#            </h4>
#            <ul>
#             <li>
#              <a href="https://associatedstudents.humboldt.edu/">
#               Associated Students
#              </a>
#             </li>
#             <li>
#              <a href="https://basicneeds.humboldt.edu/">
#               Basic Needs
#              </a>
#             </li>
#             <li>
#              <a href="https://counseling.humboldt.edu/counseling-psychological-services-new">
#               Counseling
#              </a>
#             </li>
#             <li>
#              <a href="https://deanofstudents.humboldt.edu/">
#               Dean of Students
#              </a>
#             </li>
#             <li>
#              <a href="https://housing.humboldt.edu">
#               Housing
#              </a>
#             </li>
#             <li>
#              <a href="http://www.bkstr.com/humboldtstatestore/home">
#               The Campus Store
#              </a>
#             </li>
#             <li>
#              <a href="https://www.humboldt.edu/basic-needs/food-resources">
#               Student Food Programs
#              </a>
#             </li>
#             <li>
#              <a href="https://wellbeing.humboldt.edu/">
#               Student Health &amp; Wellbeing
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Academic Resources
#            </h4>
#            <ul>
#             <li>
#              <a href="https://acac.humboldt.edu/">
#               Academic Advising
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/14536" href="/academics/programs">
#               Academic Programs List
#              </a>
#             </li>
#             <li>
#              <a href="https://catalog.humboldt.edu/">
#               Catalog
#              </a>
#             </li>
#             <li>
#              <a href="https://registrar.humboldt.edu/class-schedule">
#               Class Schedule
#              </a>
#             </li>
#             <li>
#              <a href="https://courserotations.humboldt.edu/">
#               Course Rotations
#              </a>
#             </li>
#             <li>
#              <a href="https://library.humboldt.edu/">
#               Library
#              </a>
#             </li>
#             <li>
#              <a href="https://catalog.humboldt.edu">
#               Major Academic Plans (listed on program pages)
#              </a>
#             </li>
#             <li>
#              <a href="https://registrar.humboldt.edu/">
#               Transcripts &amp; Registration
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-md-6 col-lg-3">
#            <h4 class="menu-heading">
#             Tuition &amp; Payments
#            </h4>
#            <ul>
#             <li>
#              <a href="https://commerce.cashnet.com/HUMBOLDTACH">
#               Electronic Payments
#              </a>
#             </li>
#             <li>
#              <a href="https://studentfinancialservices.humboldt.edu/">
#               Student Financial Services
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/24515" href="/student-financial-services/parking-permits">
#               Parking Permits
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </nav>
#        </div>
#        <button aria-label="Close" class="close close-resources" data-dismiss="modal" type="button">
#         Close
#         <span class="d-none">
#          Close Quick links Panel
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#     <div aria-hidden="true" aria-labelledby="Quick Links Modal" class="modal fade resource-wrap" data-parent="#resource-panels" id="site-search" tabindex="-1">
#      <div class="modal-dialog modal-dialog-centered">
#       <div class="modal-content inner d-flex flex-column flex-grow-1 justify-content-center p-4" style="min-height: 90vh;">
#        <div>
#         <div class="search-block-form humboldt-search--searchform" data-drupal-selector="search-block-form" id="block-searchform" role="search">
#          <h2>
#           Site Search
#          </h2>
#          <form accept-charset="UTF-8" action="/search/google" id="search-block-form" method="get" region="site_search">
#           <div class="search-wrap">
#            <span class="ion-ios-search">
#            </span>
#            <div class="js-form-item form-item js-form-type-search form-item-keys js-form-item-keys form-no-label">
#             <label class="visually-hidden" for="edit-keys">
#              Search
#             </label>
#             <input class="form-search" data-drupal-selector="edit-keys" id="edit-keys" maxlength="128" name="keys" placeholder="Search Cal Poly Humboldt" size="15" title="Enter the terms you wish to search for." type="search" value=""/>
#            </div>
#           </div>
#           <div class="d-lg-flex justify-content-end form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions--2">
#            <input class="button js-form-submit form-submit" data-drupal-selector="edit-submit" id="edit-submit" type="submit" value="Search"/>
#           </div>
#          </form>
#         </div>
#         <button aria-label="Close" class="close close-resources" data-dismiss="modal" type="button">
#          Close
#          <span class="d-none">
#           Close Quick links Panel
#          </span>
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <section class="nav-panel">
#     <div class="inner">
#      <div class="d-lg-flex row">
#       <div class="nav-bg col-lg-8">
#       </div>
#       <div class="nav-menus col-lg-4">
#        <div class="container-fluid">
#         <nav aria-labelledby="block-mainnavigation-menu" id="block-mainnavigation" role="navigation">
#          <h2 class="visually-hidden" id="block-mainnavigation-menu">
#           Main navigation
#          </h2>
#          <div id="main-menu">
#           <div class="menu list-unstyled menu-level menu-level--0" id="menu-level-0" parents="Home Admission &amp; Aid Academics Student Life About" region="navigation">
#            <div class="d-flex position-relative align-items-center">
#             <a href="/">
#              Home
#             </a>
#            </div>
#            <div class="d-flex position-relative align-items-center">
#             <a href="/admission-aid">
#              Admission &amp; Aid
#             </a>
#             <button aria-controls="dropdown-menu_link_content17f69ef7-e9e3-48cb-8f0d-f25a28a4cd79" aria-expanded="false" aria-label="Expand Admission &amp; Aid Menu" class="circle" data-target="#dropdown-menu_link_content17f69ef7-e9e3-48cb-8f0d-f25a28a4cd79" data-toggle="collapse" type="button">
#              <div class="button-inner">
#               <span class="ion-plus-circled">
#               </span>
#               <span class="d-none">
#                Expand Admission &amp; Aid Menu
#               </span>
#              </div>
#             </button>
#            </div>
#            <div class="collapse menu--level-0" data-parent="#menu-level-0" id="dropdown-menu_link_content17f69ef7-e9e3-48cb-8f0d-f25a28a4cd79">
#             <div class="menu-level menu-level--1 list-unstyled">
#              <h3>
#               Admission &amp; Aid	Menu
#              </h3>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/admission-aid/how-to-apply">
#                How to Apply
#               </a>
#               <button aria-controls="dropdown-menu_link_content0efee0ab-2b5c-44dc-b3c0-80e46e7c485e" aria-expanded="false" aria-label="Expand How to Apply Menu" class="circle" data-target="#dropdown-menu_link_content0efee0ab-2b5c-44dc-b3c0-80e46e7c485e" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand How to Apply Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_content0efee0ab-2b5c-44dc-b3c0-80e46e7c485e">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/how-to-apply/first-years">
#                  First-Year Students
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/how-to-apply/undergraduate/transfer">
#                  Transfer Students
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/how-to-apply/graduate">
#                  Graduate Students
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/how-to-apply/credential">
#                  Credential Students
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/how-to-apply/certificate-2nd-degree">
#                  Certificate &amp; 2nd Degree
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/how-to-apply/undergraduate/returning">
#                  Returning Students
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="https://extended.humboldt.edu/international-programs">
#                  International
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="https://veterans.humboldt.edu/getting-started">
#                  Veteran &amp; Active Military
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="https://eop.humboldt.edu">
#                  Educational Opportunity Program
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/financial-aid">
#                Financial Aid
#               </a>
#               <button aria-controls="dropdown-menu_link_content7e6ccf0f-04af-4876-918c-fcf06b9cb688" aria-expanded="false" aria-label="Expand Financial Aid Menu" class="circle" data-target="#dropdown-menu_link_content7e6ccf0f-04af-4876-918c-fcf06b9cb688" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand Financial Aid Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_content7e6ccf0f-04af-4876-918c-fcf06b9cb688">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/financial-aid/tuition-cost">
#                  Tuition &amp; Costs
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/calculator">
#                  Net Price Calculator
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/financial-aid/aid-types/scholarships-loans">
#                  Scholarships &amp; Loans
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/financial-aid/apply-for-aid">
#                  Applying for Aid
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/financial-aid/apply-for-aid/parent-resources">
#                  Info for Parents
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/admission-aid/visit">
#                Visit
#               </a>
#               <button aria-controls="dropdown-menu_link_contentfd6b31be-7797-49eb-b24e-4feeab362659" aria-expanded="false" aria-label="Expand Visit Menu" class="circle" data-target="#dropdown-menu_link_contentfd6b31be-7797-49eb-b24e-4feeab362659" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand Visit Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_contentfd6b31be-7797-49eb-b24e-4feeab362659">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/visit/schedule-visit">
#                  Schedule a Visit
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/visit/directions">
#                  Directions &amp; Maps
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/admission-aid/events">
#                Admissions Events
#               </a>
#               <button aria-controls="dropdown-menu_link_contentc25232f5-cce1-4318-85c7-3ce4a5cea455" aria-expanded="false" aria-label="Expand Admissions Events Menu" class="circle" data-target="#dropdown-menu_link_contentc25232f5-cce1-4318-85c7-3ce4a5cea455" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand Admissions Events Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_contentc25232f5-cce1-4318-85c7-3ce4a5cea455">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/fall-preview">
#                  Fall Preview
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/spring-preview">
#                  Spring Preview
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/admitted">
#                  I've Been Admitted
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/youth-color-empowerment-day">
#                  Youth of Color Empowerment Day
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/american-indian-college-motivation-day">
#                  American Indian College Motivation Day
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/making-college-happen">
#                  Making College Happen
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/events/transfer-student-week">
#                  National Transfer Student Week
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/admission-aid/contact">
#                Contact Admissions
#               </a>
#               <button aria-controls="dropdown-menu_link_contentb13cae20-5b25-42cf-be5d-d6cae56e3fdc" aria-expanded="false" aria-label="Expand Contact Admissions Menu" class="circle" data-target="#dropdown-menu_link_contentb13cae20-5b25-42cf-be5d-d6cae56e3fdc" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand Contact Admissions Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_contentb13cae20-5b25-42cf-be5d-d6cae56e3fdc">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/contact/counselors">
#                  Meet the Counselors
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/admission-aid/how-to-apply/enrollment">
#                After Applying
#               </a>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a aria-controls="dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1" aria-expanded="false" aria-label="Expand Requirements &amp; Info Menu" data-target="#dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1" data-toggle="collapse" href="">
#                Requirements &amp; Info
#               </a>
#               <button aria-controls="dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1" aria-expanded="false" aria-label="Expand Requirements &amp; Info Menu" class="circle" data-target="#dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand Requirements &amp; Info Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/requirements-info/residency">
#                  California Residency
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/requirements-info/send-transcripts">
#                  Sending Transcripts
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/requirements-info/transfer-credit">
#                  Impaction Information
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/requirements-info/subject-requirements">
#                  Subject Requirements
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="https://www2.calstate.edu/apply/eligibility-index/">
#                  Eligibility Index
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/admission-aid/requirements-info/local">
#                  Local Admission Area
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="d-flex position-relative align-items-center">
#             <a href="/academics">
#              Academics
#             </a>
#             <button aria-controls="dropdown-menu_link_contentc8f5954c-974c-4374-9669-864ea2d1d013" aria-expanded="false" aria-label="Expand Academics Menu" class="circle" data-target="#dropdown-menu_link_contentc8f5954c-974c-4374-9669-864ea2d1d013" data-toggle="collapse" type="button">
#              <div class="button-inner">
#               <span class="ion-plus-circled">
#               </span>
#               <span class="d-none">
#                Expand Academics Menu
#               </span>
#              </div>
#             </button>
#            </div>
#            <div class="collapse menu--level-0" data-parent="#menu-level-0" id="dropdown-menu_link_contentc8f5954c-974c-4374-9669-864ea2d1d013">
#             <div class="menu-level menu-level--1 list-unstyled">
#              <h3>
#               Academics	Menu
#              </h3>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/academics/programs">
#                Majors &amp; Programs
#               </a>
#               <button aria-controls="dropdown-menu_link_contenta3fb59ce-3f04-4480-bd67-7dee4fdd2021" aria-expanded="false" aria-label="Expand Majors &amp; Programs Menu" class="circle" data-target="#dropdown-menu_link_contenta3fb59ce-3f04-4480-bd67-7dee4fdd2021" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
#                 <span class="d-none">
#                  Expand Majors &amp; Programs Menu
#                 </span>
#                </div>
#               </button>
#              </div>
#              <div class="collapse menu--level-1" id="dropdown-menu_link_contenta3fb59ce-3f04-4480-bd67-7dee4fdd2021">
#               <div class="menu-level menu-level--2 list-unstyled">
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/academics/programs/undergraduate">
#                  Undergraduate Degrees
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/academics/programs/graduate">
#                  Graduate Degrees
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/academics/programs/credentials">
#                  Teaching Credentials
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/academics/programs/certificates">
#                  Certificates
#                 </a>
#                </div>
#                <div class="d-flex position-relative align-items-center">
#                 <a href="/academics/programs/minors">
#                  Minors
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="https://acac.humboldt.edu">
#                Career Services
#               </a>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/academics/facilities">
#                Facilities
#               </a>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="https://research.humboldt.edu/about/centers-institutes">
#                Centers &amp; Institutes
#               </a>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="https://research.humboldt.edu/">
#                Research
#               </a>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="https://pblc.humboldt.edu/">
#                Learning Communities
#               </a>
#              </div>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/internships">
#                Internships
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="d-flex position-relative align-items-center">
#             <a href="/student-life">
#              Student Life
#             </a>
#             <button aria-controls="dropdown-menu_link_contente891d43b-ba59-4441-a7de-dcf33ab3e947" aria-expanded="false" aria-label="Expand Student Life Menu" class="circle" data-target="#dropdown-menu_link_contente891d43b-ba59-4441-a7de-dcf33ab3e947" data-toggle="collapse" type="button">
#              <div class="button-inner">
#               <span class="ion-plus-circled">
#               </span>
#               <span class="d-none">
#                Expand Student Life Menu
#               </span>
#              </div>
#             </button>
#            </div>
#            <div class="collapse menu--level-0" data-parent="#menu-level-0" id="dropdown-menu_link_contente891d43b-ba59-4441-a7de-dcf33ab3e947">
#             <div class="menu-level menu-level--1 list-unstyled">
#              <h3>
#               Student Life	Menu
#              </h3>
#              <div class="d-flex position-relative align-items-center">
#               <a href="/housing-reslife">
#                Housing
#               </a>
#               <button aria-controls="dropdown-menu_link_contentd7a0be2d-a7be-4c0d-9d0a-d0bf7a889f81" aria-expanded="false" aria-label="Expand Housing Menu" class="circle" data-target="#dropdown-menu_link_contentd7a0be2d-a7be-4c0d-9d0a-d0bf7a889f81" data-toggle="collapse" type="button">
#                <div class="button-inner">
#                 <span class="ion-plus-circled">
#                 </span>
# ...
#                   <td>
#                    234
#                   </td>
#                   <td>
#                    517
#                   </td>
#                  </tr>
#                 </tbody>
#                </table>
#                <h3>
#                 <strong>
#                  Faculty Ethnicity
#                 </strong>
#                </h3>
#                <table>
#                 <tbody>
#                  <tr>
#                   <td rowspan="2">
#                   </td>
#                   <td colspan="2">
#                    Tenured/Tenure Track
#                   </td>
#                   <td colspan="2">
#                    Lecturer
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Female
#                   </td>
#                   <td>
#                    Male
#                   </td>
#                   <td>
#                    Female
#                   </td>
#                   <td>
#                    Male
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    American Indian/Alaska Native
#                   </td>
#                   <td>
#                    66
#                   </td>
#                   <td>
#                    0
#                   </td>
#                   <td>
#                    8
#                   </td>
#                   <td>
#                    7
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Asian
#                   </td>
#                   <td>
#                    6
#                   </td>
#                   <td>
#                    9
#                   </td>
#                   <td>
#                    4
#                   </td>
#                   <td>
#                    1
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Black
#                   </td>
#                   <td>
#                    3
#                   </td>
#                   <td>
#                    5
#                   </td>
#                   <td>
#                    3
#                   </td>
#                   <td>
#                    1
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Hispanic
#                   </td>
#                   <td>
#                    9
#                   </td>
#                   <td>
#                    7
#                   </td>
#                   <td>
#                    12
#                   </td>
#                   <td>
#                    12
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Native Hawaiian/Other Pacific Islander
#                   </td>
#                   <td>
#                    0
#                   </td>
#                   <td>
#                    0
#                   </td>
#                   <td>
#                    0
#                   </td>
#                   <td>
#                    0
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                   </td>
#                   <td>
#                    74
#                   </td>
#                   <td>
#                    82
#                   </td>
#                   <td>
#                    126
#                   </td>
#                   <td>
#                    85
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Two or More
#                   </td>
#                   <td>
#                    2
#                   </td>
#                   <td>
#                    2
#                   </td>
#                   <td>
#                    3
#                   </td>
#                   <td>
#                    5
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    Unknown
#                   </td>
#                   <td>
#                    7
#                   </td>
#                   <td>
#                    10
#                   </td>
#                   <td>
#                    20
#                   </td>
#                   <td>
#                    8
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    <strong>
#                     University Sub-Totals
#                    </strong>
#                   </td>
#                   <td>
#                    <strong>
#                     107
#                    </strong>
#                   </td>
#                   <td>
#                    <strong>
#                     115
#                    </strong>
#                   </td>
#                   <td>
#                    <strong>
#                     176
#                    </strong>
#                   </td>
#                   <td>
#                    <strong>
#                     119
#                    </strong>
#                   </td>
#                  </tr>
#                  <tr>
#                   <td>
#                    <strong>
#                     University Totals
#                    </strong>
#                   </td>
#                   <td colspan="2">
#                    <strong>
#                     222
#                    </strong>
#                   </td>
#                   <td colspan="2">
#                    <strong>
#                     295
#                    </strong>
#                   </td>
#                  </tr>
#                 </tbody>
#                </table>
#                <p>
#                </p>
#                <h3>
#                 <br/>
#                 <strong>
#                  Accessibility Assurance for Accountability and Transparency
#                 </strong>
#                </h3>
#                <p>
#                 We are committed to accessibility and are making every effort to provide our data and reports in a manner that is easy to navigate and accessible to all. If you have suggestions or have problems viewing items on this site or any of the attached documents, please e-mail the webmaster at
#                 <a href="mailto:ie@humboldt.edu">
#                 </a>
#                 <a href="mailto:irar@humboldt.edu" target="_blank">
#                  irar@humboldt.edu
#                 </a>
#                 . We appreciate your input!
#                 <a href="http://get.adobe.com/reader">
#                  Click here
#                 </a>
#                 to download Adobe Reader to view PDF files.
#                 <a href="http://www.microsoft.com/en-us/download/details.aspx?id=13">
#                  Click here
#                 </a>
#                 to download Microsoft PowerPoint Viewer.
#                </p>
#                <p>
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </article>
#      </div>
#     </main>
#     <footer id="footer">
#      <div class="container-fluid">
#       <div class="row d-lg-flex flex-column flex-lg-row justify-content-between">
#        <div class="footer-1 order-1">
#         <div class="inner">
#          <img alt="Cal Poly Humboldt" class="footer-logo" src="/themes/humboldt/images/Logo.svg"/>
#          <div id="block-footeraddress">
#           <div>
#            <p>
#             California State Polytechnic
#             <br/>
#             University, Humboldt
#             <br/>
#             1 Harpst Street
#             <br/>
#             Arcata, CA 95521
#             <br/>
#             (707) 826-3011
#            </p>
#            <p>
#             <a data-entity-substitution="canonical" data-entity-type="node" data-entity-uuid="21a650ba-1786-4228-837d-9ec92a1df529" href="/admission-aid/visit/directions" node="" style="color:#fff;" title="Directions &amp; Maps">
#              Directions &amp; Maps
#             </a>
#            </p>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="footer-2 order-3 order-lg-2 col">
#         <div class="inner d-flex flex-column flex-xl-row justify-content-between">
#          <div class="col-xl-4">
#           <nav aria-labelledby="block-legal-menu" id="block-legal" role="navigation">
#            <h2 id="block-legal-menu">
#             Legal
#            </h2>
#            <ul region="footer_2">
#             <li>
#              <a href="https://web.humboldt.edu/content/web-accessibility">
#               Web Accessibility
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/14664" href="/legal/privacy">
#               Privacy Notice
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/14663" href="/legal/dmca">
#               DMCA
#              </a>
#             </li>
#             <li>
#              <a href="https://titleix.humboldt.edu/">
#               Title IX
#              </a>
#             </li>
#             <li>
#              <a href="https://cahss.humboldt.edu/nagpra">
#               NAGRPA
#              </a>
#             </li>
#            </ul>
#           </nav>
#          </div>
#          <div class="col-xl-4">
#           <nav aria-labelledby="block-employment-menu" id="block-employment" role="navigation">
#            <h2 id="block-employment-menu">
#             Employment
#            </h2>
#            <ul region="footer_3">
#             <li>
#              <a href="https://hraps.humboldt.edu/jobs">
#               Faculty &amp; Staff Employment
#              </a>
#             </li>
#             <li>
#              <a href="https://hraps.humboldt.edu/student-employment">
#               Student Employment
#              </a>
#             </li>
#             <li>
#              <a href="https://hraps.humboldt.edu">
#               Human Resources
#              </a>
#             </li>
#             <li>
#              <a href="https://acac.humboldt.edu/">
#               Career Center
#              </a>
#             </li>
#            </ul>
#           </nav>
#          </div>
#          <div class="col-xl-4">
#           <nav aria-labelledby="block-healthsafety-menu" id="block-healthsafety" role="navigation">
#            <h2 id="block-healthsafety-menu">
#             Health &amp; Safety
#            </h2>
#            <ul region="footer_4">
#             <li>
#              <a href="http://deanofstudents.humboldt.edu/">
#               Dean of Students
#              </a>
#             </li>
#             <li>
#              <a href="http://counseling.humboldt.edu/" target="_self">
#               Counseling
#              </a>
#             </li>
#             <li>
#              <a href="http://parking.humboldt.edu/">
#               Parking
#              </a>
#             </li>
#             <li>
#              <a href="https://police.humboldt.edu/">
#               Police
#              </a>
#             </li>
#             <li>
#              <a href="https://basicneeds.humboldt.edu/resources/food">
#               Student Food Programs
#              </a>
#             </li>
#             <li>
#              <a href="https://wellbeing.humboldt.edu/">
#               Student Health &amp; Wellbeing
#              </a>
#             </li>
#             <li>
#              <a href="https://clery.humboldt.edu/content/annual-security-reports">
#               Clery Annual Security Report
#              </a>
#             </li>
#             <li>
#              <a href="https://president.humboldt.edu/ombuds">
#               Ombuds
#              </a>
#             </li>
#            </ul>
#           </nav>
#          </div>
#         </div>
#        </div>
#        <div class="footer-3 order-2 order-lg-3 col last">
#         <div class="connect-inner">
#          <div class="action-link">
#           <nav aria-labelledby="block-connectwithus-menu" id="block-connectwithus" role="navigation">
#            <h2 id="block-connectwithus-menu">
#             Connect with us
#            </h2>
#            <ul region="footer_5">
#             <li>
#              <a data-drupal-link-system-path="node/14790" href="/admission-aid/contact/counselors">
#               Admissions Counselors
#              </a>
#             </li>
#             <li>
#              <a data-drupal-link-system-path="node/14662" href="/contact">
#               Contact Humboldt
#              </a>
#             </li>
#            </ul>
#           </nav>
#          </div>
#          <ul class="social-links d-flex">
#           <li>
#            <a href="https://www.facebook.com/Humboldtcalpoly" rel="noreferrer" target="_blank" title="Facebook">
#             <i aria-hidden="true" class="fa-facebook-square">
#             </i>
#             <span class="sr-only">
#              Follow us on Facebook
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.threads.net/@humboldtpolytechnic" rel="noreferrer" target="_blank" title="Threads">
#             <i aria-hidden="true" class="fab fa-threads">
#             </i>
#             <span class="sr-only">
#              Follow us on Threads
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.flickr.com/photos/calpolyhumboldt" rel="noreferrer" target="_blank" title="FLickr">
#             <i aria-hidden="true" class="fab fa-flickr">
#             </i>
#             <span class="sr-only">
#              Follow us on Instagram
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.youtube.com/user/HumboldtOnline" rel="noreferrer" target="_blank" title="YouTube">
#             <i aria-hidden="true" class="fab fa-youtube">
#             </i>
#             <span class="sr-only">
#              Follow us on Youtube
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.linkedin.com/company/cal-poly-humboldt" rel="noreferrer" target="_blank" title="LinkedIn">
#             <i aria-hidden="true" class="fab fa-linkedin">
#             </i>
#             <span class="sr-only">
#              Follow us on LinkedIn
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.instagram.com/humboldtpolytechnic/" rel="noreferrer" target="_blank" title="Instagram">
#             <i aria-hidden="true" class="fab fa-instagram">
#             </i>
#             <span class="sr-only">
#              Follow us on Instagram
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","pathPrefix":"","currentPath":"node\/26280","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"eJx1UFFuQyEMuxB9HAkFSIE1EETC3t7thypt9KOVIiuyZcuJh_Bwymu69Xt3JXAz_oP4JSbwQBvH7EAHTOXAtRMqmjyrZ4pqI3YYWrGpWzC3kIg90E30otLS5htHdHfCn-IJXYf0EraiIA3o2S3PY4HoO_G8pJxXMv-M_HXczDFbn34lZIxGEEbI7vUCqxkrHrW0UpcxiBi5RLGuFwia74Kn2CceleMk_AXsAH--","theme":"humboldt","theme_token":null},"ajaxTrustedUrl":{"\/search\/google":true},"back_to_top":{"back_to_top_button_trigger":1100,"back_to_top_speed":1200,"back_to_top_prevent_on_mobile":false,"back_to_top_prevent_in_admin":false,"back_to_top_button_type":"image","back_to_top_button_text":"Back to top"},"search_autocomplete":{"program_search_terms":{"source":"\/program_search_autocomplete","selector":"#discover-filters input[name=\u0022program_keys\u0022]","minChars":1,"maxSuggestions":30,"autoSubmit":true,"autoRedirect":true,"theme":"minimal","filters":["q","title"],"noResult":{"group":{"group_id":"no_results"},"label":"Search Related Programs \u2192","value":"[search-phrase]","link":""},"moreResults":{"group":{"group_id":"more_results"},"label":"","value":"","link":""}}},"user":{"uid":0,"permissionsHash":"a7845c97a36c5b5901c61bbc9ad6e0de482ea16a1e5a439d5cf9f1355d8c2dba"}}
#   </script>
#   <script src="/sites/default/files/js/js_0vl-YQupar77ycYGolo8IzBBH6M6iPcmxW9JOus_bKE.js?scope=footer&amp;delta=0&amp;language=en&amp;theme=humboldt&amp;include=eJxFxkkOwCAIAMAP2fIkA0jsgmIUDv19e2syhyHkO7t9BtD_fK3ENgXKjIG6Y7ixtaHiko5oZFocqhqhbssfPXt9AWR5HaQ">
#   </script>
#   <script async="" src="https://connect.humboldt.edu/ping">
#   </script>
#  </body>
# </html>

# %%
# check for specific tags
cph_soup.find_all('a')
# Out:
# [<a class="focusable skip-link" href="#main" rel="nofollow"> Skip to main content </a>,
#  <a class="focusable skip-link" href="#" id="nav-skip" rel="nofollow"> Primary Navigation </a>,
#  <a class="focusable skip-link" href="#footer" rel="nofollow"> Site Footer </a>,
#  <a href="/"><img alt="Cal Poly Humboldt" id="logo" src="/themes/humboldt/images/Logo.svg"/><img alt="Cal Poly Humboldt H Logo" id="logoH" src="/themes/humboldt/images/logoH.svg"/></a>,
#  <a class="drop-menu-link" data-target="#student-resources" data-toggle="modal" href="#student-resources" id="drop-menu-trigger" role="button"><span class="trigger">Quick Links<span class="icon ion-ios-arrow-thin-down"></span></span></a>,
#  <a aria-expanded="false" class="search-switch nav-switch d-flex flex-column" data-target="#site-search" data-toggle="modal" href="#site-search" role="button"><div class="button-inner"><span class="icon ion-ios-search-strong"></span><span class="switch-label">Search</span></div></a>,
#  <a aria-label="open menu" class="hamburger-wrap nav-switch d-flex flex-column" href="#" id="hamburger"><div class="button-inner"><div class="hamburger hamburger--collapse" type="button"><span class="hamburger-box"><span class="hamburger-inner"></span></span></div><span class="switch-label open-label">Menu</span><span class="switch-label close-label">Close</span></div></a>,
#  <a class="home-touch" href="/irar"><span class="icon ion-ios-home"></span> IRAR</a>,
#  <a aria-controls="department-menu" aria-expanded="false" class="department-menu collapsed" data-toggle="collapse" href="#department-menu" role="button"></a>,
#  <a href="/irar"><span class="icon ion-ios-home"></span>IRAR</a>,
#  <a class="top-level" href="/irar">Home</a>,
#  <a href="/irar/got-data/got-data">Got Data?</a>,
#  <a href="/irar/got-data/admissions-data">Admissions Data</a>,
#  <a href="/irar/enrollment-data">Enrollment Data</a>,
#  <a href="/irar/got-data/course-class">Courses and Classes</a>,
#  <a href="/irar/got-data/grad-reten">Graduation and Retention </a>,
#  <a href="/irar/got-data/DEI">Diversity, Equity, and Inclusion</a>,
#  <a href="/irar/got-data/HUMIS">HUMIS Reports</a>,
#  <a href="/irar/got-data/dod">Data On Demand</a>,
#  <a href="/irar/got-data/data-glossary">Humboldt IRAR Data Glossary</a>,
#  <a class="top-level" href="/irar/january-data-viz">Data Viz</a>,
#  <a class="top-level" href="/irar/infographics">Infographics</a>,
#  <a href="/irar/institutional-research/survey-policies-and-procedures">Campus Survey Policies and Procedures</a>,
#  <a href="/irar/institutional-research/research">Institutional Research</a>,
#  <a href="/irar/institutional-research/IR-presents">Presentations</a>,
#  <a href="/irar/institutional-research/campus-research-analysis">Campus Research and Analysis</a>,
#  <a class="top-level" href="https://academicprograms.humboldt.edu/content/learning-assessment">Assessment and Program Review</a>,
#  <a class="top-level" href="/irar/welcome-data-management-page">Data Management</a>,
#  <a href="/irar/about-us/meet-team">Meet the Team</a>,
#  <a href="/irar/about-us/purpose-vision">Purpose &amp; Vision</a>,
#  <a href="/irar/about-us/outcomes">Office Outcomes and Plans</a>,
#  <a href="/irar/about-us/partners">Strategic Partner List</a>,
#  <a href="/irar/about-us/office-contact">Office Contact</a>,
#  <a href="/irar/about-us/points-pride">Points of Pride</a>,
#  <a href="https://my.humboldt.edu" target="_blank">myHumboldt</a>,
#  <a href="https://commerce.cashnet.com/HUMBOLDTACH">Make a Payment</a>,
#  <a href="https://extended.humboldt.edu/">eLearning</a>,
#  <a href="http://myhousing.humboldt.edu/">myHousing</a>,
#  <a href="/directories/site-index">A</a>,
#  <a href="/site-index/b">B</a>,
#  <a href="/site-index/c">C</a>,
#  <a href="/site-index/d">D</a>,
#  <a href="/site-index/e">E</a>,
#  <a href="/site-index/f">F</a>,
#  <a href="/site-index/g">G</a>,
#  <a href="/site-index/h">H</a>,
#  <a href="/site-index/i">I</a>,
#  <a href="/site-index/j">J</a>,
#  <a href="/site-index/k">K</a>,
#  <a href="/site-index/l">L</a>,
#  <a href="/site-index/m">M</a>,
#  <a href="/site-index/n">N</a>,
#  <a href="/site-index/o">O</a>,
#  <a href="/site-index/p">P</a>,
#  <a href="/site-index/q">Q</a>,
#  <a href="/site-index/r">R</a>,
#  <a href="/site-index/s">S</a>,
#  <a href="/site-index/t">T</a>,
#  <a href="/site-index/u">U</a>,
#  <a href="/site-index/v">V</a>,
#  <a href="/site-index/w">W</a>,
#  <a href="/site-index/x">X</a>,
#  <a href="/site-index/y">Y</a>,
#  <a href="/site-index/z">Z</a>,
#  <a data-drupal-link-system-path="node/14644" href="/academics/colleges/departments">Academic Departments</a>,
#  <a href="https://its.humboldt.edu/directory">Faculty &amp; Staff Directory</a>,
#  <a href="https://its.humboldt.edu/student-directory">Student Directory</a>,
#  <a data-drupal-link-system-path="node/14630" href="/admission-aid/visit/directions">Campus Maps</a>,
#  <a data-drupal-link-system-path="node/14654" href="/about/polytechnic/branding-initiative">Humboldt Brand</a>,
#  <a href="https://president.humboldt.edu/ombuds/">Ombuds Services</a>,
#  <a data-drupal-link-system-path="node/24353" href="/transportation-parking">Parking</a>,
#  <a href="https://police.humboldt.edu/">Police</a>,
#  <a href="/events">Calendars &amp; Events</a>,
#  <a data-drupal-link-system-path="node/25058" href="/campus-recreation">Campus Recreation</a>,
#  <a href="https://tickets.humboldt.edu/calpolyhumboldt-presents">Cal Poly Humboldt Presents</a>,
#  <a href="https://ces.humboldt.edu/community-planning">Facility Rental</a>,
#  <a data-drupal-link-system-path="node/21778" href="/academic-personnel-services">Academic Personnel Serv.</a>,
#  <a href="https://dineoncampus.com/calpolyhumboldt/faculty--staff-meal-plans">Faculty &amp; Staff Dining</a>,
#  <a href="https://kra.humboldt.edu/content/healthy-u">Healthy-U Program</a>,
#  <a data-drupal-link-system-path="node/29030" href="/hr">Human Resources</a>,
#  <a href="https://idm-prov.humboldt.edu/identity/self-service/hsu/caslogin.jsp">Account Settings</a>,
#  <a href="https://its.humboldt.edu/internet-wifi/eduroam">Internet &amp; Wifi</a>,
#  <a href="https://idm-prov.humboldt.edu/identity/self-service/hsu/smsreset.jsf">Reset Your Password</a>,
#  <a href="https://its.humboldt.edu/help/top-help-desk-issues">Technology Assistance</a>,
#  <a href="https://its.humboldt.edu/">ITS Support Request</a>,
#  <a href="https://associatedstudents.humboldt.edu/">Associated Students</a>,
#  <a href="https://basicneeds.humboldt.edu/">Basic Needs</a>,
#  <a href="https://counseling.humboldt.edu/counseling-psychological-services-new">Counseling</a>,
#  <a href="https://deanofstudents.humboldt.edu/">Dean of Students</a>,
#  <a href="https://housing.humboldt.edu">Housing</a>,
#  <a href="http://www.bkstr.com/humboldtstatestore/home">The Campus Store</a>,
#  <a href="https://www.humboldt.edu/basic-needs/food-resources">Student Food Programs</a>,
#  <a href="https://wellbeing.humboldt.edu/">Student Health &amp; Wellbeing</a>,
#  <a href="https://acac.humboldt.edu/">Academic Advising</a>,
#  <a data-drupal-link-system-path="node/14536" href="/academics/programs">Academic Programs List</a>,
#  <a href="https://catalog.humboldt.edu/">Catalog</a>,
#  <a href="https://registrar.humboldt.edu/class-schedule">Class Schedule</a>,
#  <a href="https://courserotations.humboldt.edu/">Course Rotations</a>,
#  <a href="https://library.humboldt.edu/">Library</a>,
#  <a href="https://catalog.humboldt.edu">Major Academic Plans (listed on program pages)</a>,
#  <a href="https://registrar.humboldt.edu/">Transcripts &amp; Registration</a>,
#  <a href="https://commerce.cashnet.com/HUMBOLDTACH">Electronic Payments</a>,
#  <a href="https://studentfinancialservices.humboldt.edu/">Student Financial Services</a>,
#  <a data-drupal-link-system-path="node/24515" href="/student-financial-services/parking-permits">Parking Permits</a>,
#  <a href="/">Home</a>,
#  <a href="/admission-aid">Admission &amp; Aid</a>,
#  <a href="/admission-aid/how-to-apply">How to Apply</a>,
#  <a href="/admission-aid/how-to-apply/first-years">First-Year Students</a>,
#  <a href="/admission-aid/how-to-apply/undergraduate/transfer">Transfer Students</a>,
#  <a href="/admission-aid/how-to-apply/graduate">Graduate Students</a>,
#  <a href="/admission-aid/how-to-apply/credential">Credential Students</a>,
#  <a href="/admission-aid/how-to-apply/certificate-2nd-degree">Certificate &amp; 2nd Degree</a>,
#  <a href="/admission-aid/how-to-apply/undergraduate/returning">Returning Students</a>,
#  <a href="https://extended.humboldt.edu/international-programs">International</a>,
#  <a href="https://veterans.humboldt.edu/getting-started">Veteran &amp; Active Military</a>,
#  <a href="https://eop.humboldt.edu">Educational Opportunity Program</a>,
#  <a href="/financial-aid">Financial Aid</a>,
#  <a href="/financial-aid/tuition-cost">Tuition &amp; Costs</a>,
#  <a href="/calculator">Net Price Calculator</a>,
#  <a href="/financial-aid/aid-types/scholarships-loans">Scholarships &amp; Loans</a>,
#  <a href="/financial-aid/apply-for-aid">Applying for Aid</a>,
#  <a href="/financial-aid/apply-for-aid/parent-resources">Info for Parents</a>,
#  <a href="/admission-aid/visit">Visit</a>,
#  <a href="/admission-aid/visit/schedule-visit">Schedule a Visit</a>,
#  <a href="/admission-aid/visit/directions">Directions &amp; Maps</a>,
#  <a href="/admission-aid/events">Admissions Events</a>,
#  <a href="/admission-aid/events/fall-preview">Fall Preview</a>,
#  <a href="/admission-aid/events/spring-preview">Spring Preview</a>,
#  <a href="/admission-aid/events/admitted">I've Been Admitted</a>,
#  <a href="/admission-aid/events/youth-color-empowerment-day">Youth of Color Empowerment Day</a>,
#  <a href="/admission-aid/events/american-indian-college-motivation-day">American Indian College Motivation Day</a>,
#  <a href="/admission-aid/events/making-college-happen">Making College Happen</a>,
#  <a href="/admission-aid/events/transfer-student-week">National Transfer Student Week</a>,
#  <a href="/admission-aid/contact">Contact Admissions</a>,
#  <a href="/admission-aid/contact/counselors">Meet the Counselors</a>,
#  <a href="/admission-aid/how-to-apply/enrollment">After Applying</a>,
#  <a aria-controls="dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1" aria-expanded="false" aria-label="Expand Requirements &amp; Info Menu" data-target="#dropdown-menu_link_content943c1229-6740-46d8-b834-add201cf82d1" data-toggle="collapse" href="">Requirements &amp; Info</a>,
#  <a href="/admission-aid/requirements-info/residency">California Residency</a>,
#  <a href="/admission-aid/requirements-info/send-transcripts">Sending Transcripts</a>,
#  <a href="/admission-aid/requirements-info/transfer-credit">Impaction Information</a>,
#  <a href="/admission-aid/requirements-info/subject-requirements">Subject Requirements</a>,
#  <a href="https://www2.calstate.edu/apply/eligibility-index/">Eligibility Index</a>,
#  <a href="/admission-aid/requirements-info/local">Local Admission Area</a>,
#  <a href="/academics">Academics</a>,
#  <a href="/academics/programs">Majors &amp; Programs</a>,
#  <a href="/academics/programs/undergraduate">Undergraduate Degrees</a>,
#  <a href="/academics/programs/graduate">Graduate Degrees</a>,
#  <a href="/academics/programs/credentials">Teaching Credentials</a>,
#  <a href="/academics/programs/certificates">Certificates</a>,
#  <a href="/academics/programs/minors">Minors</a>,
#  <a href="https://acac.humboldt.edu">Career Services</a>,
#  <a href="/academics/facilities">Facilities</a>,
#  <a href="https://research.humboldt.edu/about/centers-institutes">Centers &amp; Institutes</a>,
#  <a href="https://research.humboldt.edu/">Research</a>,
#  <a href="https://pblc.humboldt.edu/">Learning Communities</a>,
#  <a href="/internships">Internships</a>,
#  <a href="/student-life">Student Life</a>,
#  <a href="/housing-reslife">Housing</a>,
#  <a href="/housing-reslife/cost-options/housing-options">Housing Options</a>,
#  <a href="/housing-reslife/resident-resources/moving-in">Moving-in</a>,
#  <a href="/sustainable-campus/green-room">Sustainable Living</a>,
#  <a href="/housing-reslife/cost-options/theme-housing">Themed Housing</a>,
#  <a href="/student-life/dining">Dining</a>,
#  <a href="https://dineoncampus.com/calpolyhumboldt/dining-location-map">Locations</a>,
#  <a href="https://dineoncampus.com/calpolyhumboldt/whats-on-todays-menu">Menus</a>,
#  <a href="https://dineoncampus.com/calpolyhumboldt/oncampus-resident-meal-plans">Meal Plans</a>,
#  <a href="https://clubs.humboldt.edu">Clubs &amp; Organizations</a>,
#  <a href="/campus-recreation">Campus Recreation</a>,
#  <a href="https://wellbeing.humboldt.edu/">Health &amp; Wellbeing</a>,
#  <a href="/sac">Gutswurrak Student Activities Center</a>,
#  <a href="/events">Events</a>,
#  <a href="/about">About</a>,
#  <a href="/about/why">Why Cal Poly Humboldt?</a>,
#  <a href="/about/purpose-vision">Purpose &amp; Vision</a>,
#  <a href="/about/polytechnic">Polytechnic Information</a>,
#  <a href="/about/polytechnic/planning">Polytechnic Planning</a>,
#  <a href="/about/polytechnic/infrastructure-projects">Infrastructure Projects</a>,
#  <a href="/about/polytechnic/academic-programming-build-out">Academic Programming Build-out</a>,
#  <a href="/about/polytechnic/branding-initiative">Branding Initiative</a>,
#  <a href="/about/polytechnic/implementation-working-group-charge">Implementation Charge</a>,
#  <a href="/about/polytechnic/implementation-working-groups">Implementation Working Groups</a>,
#  <a href="/about/polytechnic/working-groups">Self-Study Working Groups</a>,
#  <a href="/about/polytechnic/updates">Polytechnic Updates</a>,
#  <a href="/about/diversity-inclusion">Diversity, Equity &amp; Inclusion</a>,
#  <a href="https://diversity.humboldt.edu/">Policies &amp; Initiatives</a>,
#  <a href="https://hsi.humboldt.edu/">HSI Designation</a>,
#  <a href="/ciace">Centers for Inclusive Academic &amp; Career Excellence</a>,
#  <a href="https://umoja.humboldt.edu/">Pan African Center</a>,
#  <a href="https://itepp.humboldt.edu/">Native American Center</a>,
#  <a href="https://lcae.humboldt.edu/">El Centro</a>,
#  <a href="https://sjei.humboldt.edu/">Social Justice, Equity, &amp; Inclusion Center</a>,
#  <a href="/sustainable-campus">Sustainability</a>,
#  <a aria-controls="dropdown-menu_link_content32f298d2-f193-48e1-8a37-3fa1f7eddea1" aria-expanded="false" aria-label="Expand Administrative Offices Menu" data-target="#dropdown-menu_link_content32f298d2-f193-48e1-8a37-3fa1f7eddea1" data-toggle="collapse" href="">Administrative Offices</a>,
#  <a href="https://president.humboldt.edu/">President</a>,
#  <a href="https://aavp.humboldt.edu/">Academic Affairs</a>,
#  <a href="https://adminaffairs.humboldt.edu/">Administrative Affairs</a>,
#  <a href="https://enrollmentmanagement.humboldt.edu/">Enrollment Management</a>,
#  <a href="https://advancement.humboldt.edu/">University Advancement</a>,
#  <a href="https://humboldtathletics.com/index.aspx">Athletics</a>,
#  <a href="/sites/default/files/2023-01/hsu_orgchart.pdf">University Org. Chart</a>,
#  <a href="/about/facts-figures">Facts &amp; Figures</a>,
#  <a href="/about/our-history">Our History</a>,
#  <a href="/admission-aid/visit/directions#maps">Campus Maps</a>,
#  <a aria-label="Expand Quick Links Resources Menu" class="drop-menu-link" data-target="#student-resources" data-toggle="modal" href='="#student-resources"' role="button">Quick Links</a>,
#  <a href="https://humboldtathletics.com/splash.aspx?id=splash_136" target="_blank">Athletics</a>,
#  <a href="https://forever.humboldt.edu/" target="_blank">Alumni</a>,
#  <a href="https://family.humboldt.edu/" target="_blank">Parents &amp; Families</a>,
#  <a href="/events">Events</a>,
#  <a href="https://now.humboldt.edu">News</a>,
#  <a class="button ghost" href="https://giving.humboldt.edu/"><span>Give</span></a>,
#  <a data-drupal-link-system-path="node/14631" href="/admission-aid/visit/schedule-visit">Schedule a Visit</a>,
#  <a href="https://connect.humboldt.edu/register/inquiryform">Request Info</a>,
#  <a data-drupal-link-system-path="node/14538" href="/admission-aid/how-to-apply">Apply</a>,
#  <a href="https://www.humboldt.edu/immigration" style="color:#004C46;"><strong>Immigration Rights and Resources</strong></a>,
#  <a href="https://www.humboldt.edu/free-speech" style="color:#004C46;"><strong>Free Speech</strong></a>,
#  <a name="top"></a>,
#  <a href="/">Home</a>,
#  <a href="/irar">IRAR</a>,
#  <a class="button ghost" href="https://www.humboldt.edu/irar/fall-semester-fast-facts" target=""><span>Fast Facts - Current</span></a>,
#  <a class="button ghost" href="https://www.humboldt.edu/irar/fast-facts-fall-2023" target=""><span>Fast Facts 2023</span></a>,
#  <a class="button ghost" href="https://www.humboldt.edu/irar/fast-facts-f21" target=""><span>Fast Facts 2021</span></a>,
#  <a class="button ghost" href="https://www.humboldt.edu/irar/fast-facts-fall-2024" target=""><span>Fast Facts 2024</span></a>,
#  <a class="button ghost" href="https://www.humboldt.edu/irar/fast-facts-f22" target=""><span>Fast Facts 2022</span></a>,
#  <a class="button ghost" href="https://www.humboldt.edu/irar/fast-facts-f20" target=""><span>Fast Facts 2020</span></a>,
#  <a href="mailto:ie@humboldt.edu"> </a>,
#  <a href="mailto:irar@humboldt.edu" target="_blank">irar@humboldt.edu</a>,
#  <a href="http://get.adobe.com/reader">Click here</a>,
#  <a href="http://www.microsoft.com/en-us/download/details.aspx?id=13">Click here</a>,
#  <a data-entity-substitution="canonical" data-entity-type="node" data-entity-uuid="21a650ba-1786-4228-837d-9ec92a1df529" href="/admission-aid/visit/directions" node="" style="color:#fff;" title="Directions &amp; Maps">Directions &amp; Maps</a>,
#  <a href="https://web.humboldt.edu/content/web-accessibility">Web Accessibility</a>,
#  <a data-drupal-link-system-path="node/14664" href="/legal/privacy">Privacy Notice</a>,
#  <a data-drupal-link-system-path="node/14663" href="/legal/dmca">DMCA</a>,
#  <a href="https://titleix.humboldt.edu/">Title IX</a>,
#  <a href="https://cahss.humboldt.edu/nagpra">NAGRPA</a>,
#  <a href="https://hraps.humboldt.edu/jobs">Faculty &amp; Staff Employment</a>,
#  <a href="https://hraps.humboldt.edu/student-employment">Student Employment</a>,
#  <a href="https://hraps.humboldt.edu">Human Resources</a>,
#  <a href="https://acac.humboldt.edu/">Career Center</a>,
#  <a href="http://deanofstudents.humboldt.edu/">Dean of Students</a>,
#  <a href="http://counseling.humboldt.edu/" target="_self">Counseling</a>,
#  <a href="http://parking.humboldt.edu/">Parking</a>,
#  <a href="https://police.humboldt.edu/">Police</a>,
#  <a href="https://basicneeds.humboldt.edu/resources/food">Student Food Programs</a>,
#  <a href="https://wellbeing.humboldt.edu/">Student Health &amp; Wellbeing</a>,
#  <a href="https://clery.humboldt.edu/content/annual-security-reports">Clery Annual Security Report</a>,
#  <a href="https://president.humboldt.edu/ombuds">Ombuds</a>,
#  <a data-drupal-link-system-path="node/14790" href="/admission-aid/contact/counselors">Admissions Counselors</a>,
#  <a data-drupal-link-system-path="node/14662" href="/contact">Contact Humboldt</a>,
#  <a href="https://www.facebook.com/Humboldtcalpoly" rel="noreferrer" target="_blank" title="Facebook"><i aria-hidden="true" class="fa-facebook-square"></i><span class="sr-only">Follow us on Facebook</span></a>,
#  <a href="https://www.threads.net/@humboldtpolytechnic" rel="noreferrer" target="_blank" title="Threads"><i aria-hidden="true" class="fab fa-threads"></i><span class="sr-only">Follow us on Threads</span></a>,
#  <a href="https://www.flickr.com/photos/calpolyhumboldt" rel="noreferrer" target="_blank" title="FLickr"><i aria-hidden="true" class="fab fa-flickr"></i><span class="sr-only">Follow us on Instagram</span></a>,
#  <a href="https://www.youtube.com/user/HumboldtOnline" rel="noreferrer" target="_blank" title="YouTube"><i aria-hidden="true" class="fab fa-youtube"></i><span class="sr-only">Follow us on Youtube</span></a>,
#  <a href="https://www.linkedin.com/company/cal-poly-humboldt" rel="noreferrer" target="_blank" title="LinkedIn"><i aria-hidden="true" class="fab fa-linkedin"></i><span class="sr-only">Follow us on LinkedIn</span></a>,
#  <a href="https://www.instagram.com/humboldtpolytechnic/" rel="noreferrer" target="_blank" title="Instagram"><i aria-hidden="true" class="fab fa-instagram"></i><span class="sr-only">Follow us on Instagram</span></a>]

# %%
# refine the search with css selectors
cph_soup.find_all('a', class_ = "top-level")
# Out:
# [<a class="top-level" href="/irar">Home</a>,
#  <a class="top-level" href="/irar/january-data-viz">Data Viz</a>,
#  <a class="top-level" href="/irar/infographics">Infographics</a>,
#  <a class="top-level" href="https://academicprograms.humboldt.edu/content/learning-assessment">Assessment and Program Review</a>,
#  <a class="top-level" href="/irar/welcome-data-management-page">Data Management</a>]

# %%
# A shorthand way of searching that
cph_soup.select('a.top-level')

# %%
# How many tables are there?
len(cph_soup.find_all('table'))

# %% [markdown]
# There are multiple tables on the page. The trick to finding the right one is to look at nearby HTML landmarks — headings, IDs, or class names that label each section. Here we check the `<h3>` headers to pair them up with the table index we want.

# %%
# Tables are labeled with h3 headers
cph_soup.find_all('h3')

# %%
# Let's just focus on one of the tables
#  just look at the website to select the 3rd indexed table

student_ethnicity_table = cph_soup.find_all('table')[3]
student_ethnicity_table


# another method if you are looking for the h3 that points to a table
#     you search the h3 for matching term
#     then we use .find_next('table') to return the next table element

#target_h3 = cph_soup.find('h3', string=lambda t: t and 'Ethnicity' in t)
#target_table = target_h3.find_next('table')
# Out:
# <table><tbody><tr><td> </td><td>Female</td><td>Male</td><td>Totals</td><td>Percentage</td></tr><tr><td>American Indian</td><td>66</td><td>31</td><td>97</td><td>1.5%</td></tr><tr><td>Asian</td><td>90</td><td>102</td><td>192</td><td>3.1%</td></tr><tr><td>Black</td><td>90</td><td>81</td><td>171</td><td>2.7%</td></tr><tr><td>Hispanic/Latino</td><td>989</td><td>801</td><td>1790</td><td>28.5%</td></tr><tr><td>Pacific Islander</td><td>6</td><td>10</td><td>16</td><td>0.3%</td></tr><tr><td>Two or more</td><td>247</td><td>233</td><td>480</td><td>7.6%</td></tr><tr><td>Unknown</td><td>128</td><td>161</td><td>289</td><td>4.6%</td></tr><tr><td>White</td><td>1729</td><td>1463</td><td>3192</td><td>50.9%</td></tr><tr><td>U.S. Nonresident</td><td>26</td><td>23</td><td>49</td><td>0.8%</td></tr><tr><td><strong>Totals</strong></td><td><strong>3371</strong></td><td><strong>2905</strong></td><td><strong>6276</strong></td><td><strong>100.0%</strong></td></tr></tbody></table>

# %% [markdown]
# An HTML table is nested three levels deep:
# - **`<table>`** — the whole table
# - **`<tr>`** — a table row
# - **`<td>`** — an individual data cell (`<th>` for header cells)
#
# To reach a single value, drill down: table → rows → cells → `.text`.

# %%
# Look at the rows
student_ethnicity_table.find_all('tr')

# %%
# Look at a single row
student_ethnicity_table.find_all('tr')[0]

# %%
# Look at all the data points in that row
student_ethnicity_table.find_all('tr')[0].find_all('td')

# %%
# Look at one specific data point
student_ethnicity_table.find_all('tr')[0].find_all('td')[1]

# %%
# Get the text of that data point 
student_ethnicity_table.find_all('tr')[0].find_all('td')[1].text

# %% [markdown]
# ---
# ### Try It 2: Navigate a Table on the CPH Page 😊
#
# Use the `cph_soup` object from the Cal Poly Humboldt page.
#
# 1. Print the `<h3>` text that appears just before each table on the page, so you know what each table contains.
#
# 2. Pick any table that is **not** `student_ethnicity_table`. Extract the text from its first data row as a Python list.
#
# 3. Use `cph_soup.select()` with a CSS selector to find all `<a>` elements with class `'top-level'`. How many are there, and what text do they display?

# %%
# 1. Print h3 label paired with each table

# %%
# 2. First data row from a different table

# %%
# 3. CSS selector for a.top-level

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# ```python
# # 1.
# headers = cph_soup.find_all('h3')
# tables  = cph_soup.find_all('table')
# for h, t in zip(headers, tables):
#     print(h.text.strip())
#
# # 2.
# other_table = cph_soup.find_all('table')[0]
# first_row   = other_table.find_all('tr')[0]
# [cell.text.strip() for cell in first_row.find_all('td')]
#
# # 3.
# links = cph_soup.select('a.top-level')
# print(len(links))
# [a.text for a in links]
# ```
#
# </details>

# %% [markdown]
# ---
# ## 4. Building a DataFrame from Scraped Tables
#
# Two approaches: a manual loop, or the `pd.read_html()` shortcut.

# %% [markdown]
# ### Manual approach — nested loop

# %% [markdown]
# The goal is to convert the HTML table into a list of lists — one inner list per row, one string per cell — then hand that to `pd.DataFrame()`. The outer loop walks rows (`<tr>`), the inner loop walks cells (`<td>`) within each row.

# %%
# Create a nested list with the data
table_vals = []

for i in student_ethnicity_table.find_all('tr'):
    row_i = []
    for j in i.find_all('td'):
        row_i.append(j.text)
    table_vals.append(row_i)

# %%
# Check out the result
table_vals
# Out:
# [['\xa0', 'Female', 'Male', 'Totals', 'Percentage'],
#  ['American Indian', '66', '31', '97', '1.5%'],
#  ['Asian', '90', '102', '192', '3.1%'],
#  ['Black', '90', '81', '171', '2.7%'],
#  ['Hispanic/Latino', '989', '801', '1790', '28.5%'],
#  ['Pacific Islander', '6', '10', '16', '0.3%'],
#  ['Two or more', '247', '233', '480', '7.6%'],
#  ['Unknown', '128', '161', '289', '4.6%'],
#  ['White', '1729', '1463', '3192', '50.9%'],
#  ['U.S. Nonresident', '26', '23', '49', '0.8%'],
#  ['Totals', '3371', '2905', '6276', '100.0%']]

# %% [markdown]
# The raw result has two things to fix:
# - **Row 0 is actually the header** — HTML header cells (`<th>`) were treated the same as data cells (`<td>`), so the column labels landed in row 0 as data. We need to promote them.
# - **`\xa0`** — this is HTML's non-breaking space (`&nbsp;`). It appears wherever the page used `&nbsp;` for formatting and becomes a literal `\xa0` character when scraped. Watch for it as a phantom index label or cell value.

# %%
# Make it a dataframe
df = pd.DataFrame(table_vals)
df


# notice cell [0,0] is emptpy...not even a ``
#   there is an invisible \ax0 there?
# Out:
#                    0       1     2       3           4
# 0                     Female  Male  Totals  Percentage
# 1    American Indian      66    31      97        1.5%
# 2              Asian      90   102     192        3.1%
# 3              Black      90    81     171        2.7%
# 4    Hispanic/Latino     989   801    1790       28.5%
# 5   Pacific Islander       6    10      16        0.3%
# 6        Two or more     247   233     480        7.6%
# 7            Unknown     128   161     289        4.6%
# 8              White    1729  1463    3192       50.9%
# 9   U.S. Nonresident      26    23      49        0.8%
# 10            Totals    3371  2905    6276      100.0%

# %%
# Clean it up (reset column labels)
df.columns = df.iloc[0]
df.drop(0,inplace=True)
df
# Out:
# 0                    Female  Male Totals Percentage
# 1    American Indian     66    31     97       1.5%
# 2              Asian     90   102    192       3.1%
# 3              Black     90    81    171       2.7%
# 4    Hispanic/Latino    989   801   1790      28.5%
# 5   Pacific Islander      6    10     16       0.3%
# 6        Two or more    247   233    480       7.6%
# 7            Unknown    128   161    289       4.6%
# 8              White   1729  1463   3192      50.9%
# 9   U.S. Nonresident     26    23     49       0.8%
# 10            Totals   3371  2905   6276     100.0%

# %%
# weird \axa0

df.columns[0]
# Out:
# '\xa0'

# %%
# Clean it up (reset row labels)
# make sure to get rid of the \axa0


df.set_index('\xa0',inplace=True)

# %%
df
# Out:
# 0                Female  Male Totals Percentage
#
# American Indian      66    31     97       1.5%
# Asian                90   102    192       3.1%
# Black                90    81    171       2.7%
# Hispanic/Latino     989   801   1790      28.5%
# Pacific Islander      6    10     16       0.3%
# Two or more         247   233    480       7.6%
# Unknown             128   161    289       4.6%
# White              1729  1463   3192      50.9%
# U.S. Nonresident     26    23     49       0.8%
# Totals             3371  2905   6276     100.0%

# %%
# Would require further cleanup
df.dtypes

# %% [markdown]
# Writing a nested loop every time you want a table is tedious. Pandas has a built-in shortcut: **`pd.read_html()`** — give it an HTML string, and it finds every `<table>` element and returns a list of DataFrames automatically. The one catch: it expects a *string*, not a BeautifulSoup object, so we wrap with `str()` first.

# %% [markdown]
# ### Pandas shortcut — pd.read_html()

# %%
# We've taken a chunk of html that we want to parse
student_ethnicity_table

# %%
# What is the type
type(student_ethnicity_table)

# %%
# Read the html into a dataframe
pd.read_html(io.StringIO(str(student_ethnicity_table)))[0]

# %%
# We can use it on the whole page if we want to
pd.read_html(io.StringIO(cph_stats.text))

# %% [markdown]
# ---
# ### Try It 3: Build and Clean a Scraped DataFrame 😊
#
# Use `student_ethnicity_table` and the `df` DataFrame built with the manual loop.
#
# 1. The `df` index is named `\xa0` which is a non-breaking space artifact from the HTML. Rename the index to `'Ethnicity'` so the DataFrame is properly labeled.
#
# 2. The count columns were scraped as strings. Pick one column and convert it to a numeric dtype. What character in the values might cause `int()` to fail, and how do you handle it? How would you change the `Percentage` to a `float` type?
#
# 3. Run `pd.read_html(io.StringIO(str(student_ethnicity_table)))[0]` and compare it to your manually-cleaned `df`. Does `pd.read_html()` handle the `\xa0` and column headers automatically, or do you still need to clean it?

# %%
# 1. Rename the \xa0 index to 'Ethnicity'

# %%
# 2a. Convert a count column from string to numeric




# 2b. Convert `Percentage` to `float`
# Out:
#
# American Indian       1.5
# Asian                 3.1
# Black                 2.7
# Hispanic/Latino      28.5
# Pacific Islander      0.3
# Two or more           7.6
# Unknown               4.6
# White                50.9
# U.S. Nonresident      0.8
# Totals              100.0
# Name: Percentage, dtype: str

# %%
# 3. Compare pd.read_html() output to manual approach
# Out:
#                    0       1     2       3           4
# 0                NaN  Female  Male  Totals  Percentage
# 1    American Indian      66    31      97        1.5%
# 2              Asian      90   102     192        3.1%
# 3              Black      90    81     171        2.7%
# 4    Hispanic/Latino     989   801    1790       28.5%
# 5   Pacific Islander       6    10      16        0.3%
# 6        Two or more     247   233     480        7.6%
# 7            Unknown     128   161     289        4.6%
# 8              White    1729  1463    3192       50.9%
# 9   U.S. Nonresident      26    23      49        0.8%
# 10            Totals    3371  2905    6276      100.0%

# %% [markdown]
# <details>
# <summary>💡 Possible answers — click to peek</summary>
# <br>
#
# *`\xa0` is the HTML non-breaking space. Commas in numbers like `'1,234'` will break `int()` — strip them first with `.str.replace()`.*
#
# ```python
# # 1.
# df.index.name = 'Ethnicity'
#
# # 2.
# df['Percentage'] = df['Percentage'].str.replace('%', '').astype(float)
#
# # 3.
# clean = pd.read_html(str(student_ethnicity_table))[0]
# clean
# # pd.read_html() usually handles column headers automatically
# # but may still carry \xa0 in cell values — check clean.dtypes
# ```
#
# </details>

# %% [markdown]
# ---
# ## 5. 🔬 Activity — Humboldt Geographic Data

# %% [markdown]
# ---
# ### Scrape & Clean a Table
#
# 1. Identify the table **Fall 2025 Geographic Origin of Current Students** from the soup object that we created called `cph_soup`.
#
# 2. Pull out the data from the table using a loop. Then, convert your list into a `DataFrame`.
#
# 4. Clean the DataFrame: fix column names, fix the index name, fix dtypes, and remove any artifacts from the HTML structure.
#
# 5. **Lastly:** Use `pd.read_html()` as a shortcut instead. Does it give a cleaner result?

# %%
# 1. Identify the  the Geographic Origin table

target2 = cph_soup.find('h3', string=lambda t: t and 'Geographic Origin' in t)
target_table2 = target2.find_next('table')
# Out:
# [['Region', 'Undergraduate', 'Post Baccalaureate', 'Totals', 'Percentage'],
#  ['Local', '851', '278', '1129', '18.0%'],
#  ['Northern CA', '825', '52', '877', '14.0%'],
#  ['SF Bay Area', '798', '24', '822', '13.1%'],
#  ['Sacramento', '302', '5', '307', '4.9%'],
#  ['Coast', '296', '35', '331', '5.3%'],
#  ['Central CA', '402', '16', '418', '6.7%'],
#  ['Los Angeles', '1309', '41', '1350', '21.5%'],
#  ['San Diego', '373', '22', '395', '6.3%'],
#  ['WUE States*', '358', '50', '408', '6.5%'],
#  ['Other States', '144', '65', '209', '3.3%'],
#  ['Foreign', '19', '11', '30', '0.5%'],
#  ['Totals', '5677', '599', '6276', '100.0%']]

# %%
# 2. Now turn scrape out the  a table using a loop

df2=[]
for i in target_table2.find_all('tr'):
    row = []
    for j in i.find_all('td'):
        row.append(j.text)
    df2.append(row)
df2 = pd.DataFrame(df2)

df2
# Out:
#                0              1                   2       3           4
# 0         Region  Undergraduate  Post Baccalaureate  Totals  Percentage
# 1          Local            851                 278    1129       18.0%
# 2    Northern CA            825                  52     877       14.0%
# 3    SF Bay Area            798                  24     822       13.1%
# 4     Sacramento            302                   5     307        4.9%
# 5          Coast            296                  35     331        5.3%
# 6     Central CA            402                  16     418        6.7%
# 7    Los Angeles           1309                  41    1350       21.5%
# 8      San Diego            373                  22     395        6.3%
# 9    WUE States*            358                  50     408        6.5%
# 10  Other States            144                  65     209        3.3%
# 11       Foreign             19                  11      30        0.5%
# 12        Totals           5677                 599    6276      100.0%

# %%
# 3. Clean the DataFrame

# rename the columns

df2.rename(columns = {0:'Region', 1: 'Undergraduate', 2:'Post Baccalaureate', 3:'Totals', 4: 'Percentage'}, inplace=True)
df2


# possibly clean up that first row!
df2.drop(0, inplace=True)


# make the index -> Region
df2.set_index('Region')
# Out:
#              Undergraduate Post Baccalaureate Totals Percentage
# Region
# Local                  851                278   1129      18.0%
# Northern CA            825                 52    877      14.0%
# SF Bay Area            798                 24    822      13.1%
# Sacramento             302                  5    307       4.9%
# Coast                  296                 35    331       5.3%
# Central CA             402                 16    418       6.7%
# Los Angeles           1309                 41   1350      21.5%
# San Diego              373                 22    395       6.3%
# WUE States*            358                 50    408       6.5%
# Other States           144                 65    209       3.3%
# Foreign                 19                 11     30       0.5%
# Totals                5677                599   6276     100.0%

# %%
# 3. Clean the DataFrame cont

# check out the dataypes
#   change if necessary....(it is!)

# %%
# 4. Try pd.read_html() shortcut

# %% [markdown]
# ---
# ## Appendix — Web Scraping Quick Reference
#
# ### Minimal template
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# site = requests.get('https://example.com')
# soup = BeautifulSoup(site.text, 'html.parser')
#
# soup.find('h1')            # first h1 element
# soup.find_all('p')         # all paragraphs
# soup.find('a')['href']     # link URL
# soup.find('a').text        # link text
# ```
#
# ### CSS selectors
# ```python
# soup.find_all('a', class_='nav')   # by class
# soup.select('a.nav')               # CSS selector shorthand
# ```
#
# ### Table → DataFrame
# ```python
# # Manual loop
# table = soup.find_all('table')[0]
# rows = [[cell.text for cell in row.find_all('td')]
#         for row in table.find_all('tr')]
# df = pd.DataFrame(rows)
#
# # Shortcut
# pd.read_html(str(table))[0]
# pd.read_html(site.text)     # all tables on the page
# ```
