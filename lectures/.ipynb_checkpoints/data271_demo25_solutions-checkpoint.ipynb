# %% [markdown]
# # Preparing Data: Adding Columns
# If you want to type along with me, use [this notebook](https://humboldt.cloudbank.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fbethanyj0%2Fdata271_sp24&branch=main&urlpath=tree%2Fdata271_sp24%2Fdemos%2Fdata271_demo25_live.ipynb) instead.
# If you don't want to type and want to follow along just by executing the cells, stay in this notebook.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import re
sns.set_style("darkgrid")
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Adding independent columns

# %% [markdown]
# ### Method 1: Add to the end

# %%
# Creating animals dataframe
animals_dct = {
    'Animal': ['cow', 'kitten', 'penguin', 'Puppy'],
    'Sound': ['moo', 'purr', 'chirp', 'bark'],
}

animals = pd.DataFrame(animals_dct)
animals
# Out:
#     Animal  Sound
# 0      cow    moo
# 1   kitten   purr
# 2  penguin  chirp
# 3    Puppy   bark

# %%
# add a column on the right (broadcasting)
animals['Cute score'] = 10
animals
# Out:
#     Animal  Sound  Cute score
# 0      cow    moo          10
# 1   kitten   purr          10
# 2  penguin  chirp          10
# 3    Puppy   bark          10

# %%
# add a column on the right (list)
animals = pd.DataFrame(animals_dct)
animals['Cute score'] = [10,9.9,10,10]
animals
# Out:
#     Animal  Sound  Cute score
# 0      cow    moo        10.0
# 1   kitten   purr         9.9
# 2  penguin  chirp        10.0
# 3    Puppy   bark        10.0

# %% [markdown]
# ### Method 2: Insert the column in specific position

# %%
# Insert at a specific position with .insert(loc, column, value)
animals = pd.DataFrame(animals_dct)
animals.insert(1,'Cute score',10)
animals
# Out:
#     Animal  Cute score  Sound
# 0      cow          10    moo
# 1   kitten          10   purr
# 2  penguin          10  chirp
# 3    Puppy          10   bark

# %%
# or do it with a list
animals = pd.DataFrame(animals_dct)
animals.insert(1,'Cute score',[10,9.9,10,10])
animals
# Out:
#     Animal  Cute score  Sound
# 0      cow        10.0    moo
# 1   kitten         9.9   purr
# 2  penguin        10.0  chirp
# 3    Puppy        10.0   bark

# %% [markdown]
# ### Method 3: Add more than 1 column at once

# %%
# create two columns at once
animals = animals.assign(Adjective = ['adorable','playful','tough','cuddly'], Pet = [False,True,False,True])

# %%
animals
# Out:
#     Animal  Cute score  Sound Adjective    Pet
# 0      cow        10.0    moo  adorable  False
# 1   kitten         9.9   purr   playful   True
# 2  penguin        10.0  chirp     tough  False
# 3    Puppy        10.0   bark    cuddly   True

# %% [markdown]
# ## Adding columns based on other columns

# %%
# Making a bool column based on condition
animals['Is Cute'] = animals['Cute score'] > 5
animals.head()
# Out:
#     Animal  Cute score  Sound Adjective    Pet  Is Cute
# 0      cow        10.0    moo  adorable  False     True
# 1   kitten         9.9   purr   playful   True     True
# 2  penguin        10.0  chirp     tough  False     True
# 3    Puppy        10.0   bark    cuddly   True     True

# %%
# Making a categorical column based on another categorical column with map
animals['Can Own'] = animals['Pet'].map({True:'yes',False:'no'})
animals.head()
# Out:
#     Animal  Cute score  Sound Adjective    Pet  Is Cute Can Own
# 0      cow        10.0    moo  adorable  False     True      no
# 1   kitten         9.9   purr   playful   True     True     yes
# 2  penguin        10.0  chirp     tough  False     True      no
# 3    Puppy        10.0   bark    cuddly   True     True     yes

# %%
# applying a function to everything in another column
animals['Rounded Score'] = animals['Cute score'].apply(round)
animals.head()
# Out:
#     Animal  Cute score  Sound Adjective    Pet  Is Cute Can Own  Rounded Score
# 0      cow        10.0    moo  adorable  False     True      no             10
# 1   kitten         9.9   purr   playful   True     True     yes             10
# 2  penguin        10.0  chirp     tough  False     True      no             10
# 3    Puppy        10.0   bark    cuddly   True     True     yes             10

# %%
# Creating new columns with element-wise arithmetic
animals['Cute & Pet'] = animals['Cute score'] + animals['Pet']
animals.head()
# Out:
#     Animal  Cute score  Sound Adjective    Pet  Is Cute Can Own  \
# 0      cow        10.0    moo  adorable  False     True      no
# 1   kitten         9.9   purr   playful   True     True     yes
# 2  penguin        10.0  chirp     tough  False     True      no
# 3    Puppy        10.0   bark    cuddly   True     True     yes
#
#    Rounded Score  Cute & Pet
# 0             10        10.0
# 1             10        10.9
# 2             10        10.0
# 3             10        11.0

# %%
# With string methods
animals['First letter'] = animals['Animal'].str[0]
animals.head()
# Out:
#     Animal  Cute score  Sound Adjective    Pet  Is Cute Can Own  \
# 0      cow        10.0    moo  adorable  False     True      no
# 1   kitten         9.9   purr   playful   True     True     yes
# 2  penguin        10.0  chirp     tough  False     True      no
# 3    Puppy        10.0   bark    cuddly   True     True     yes
#
#    Rounded Score  Cute & Pet First letter
# 0             10        10.0            c
# 1             10        10.9            k
# 2             10        10.0            p
# 3             10        11.0            P

# %%
# With list comprehension
animals['starts with p'] = ['yes' if re.search('[Pp]',i) else 'no' for i in animals['First letter']]
animals.head()
# Out:
#     Animal  Cute score  Sound Adjective    Pet  Is Cute Can Own  \
# 0      cow        10.0    moo  adorable  False     True      no
# 1   kitten         9.9   purr   playful   True     True     yes
# 2  penguin        10.0  chirp     tough  False     True      no
# 3    Puppy        10.0   bark    cuddly   True     True     yes
#
#    Rounded Score  Cute & Pet First letter starts with p
# 0             10        10.0            c            no
# 1             10        10.9            k            no
# 2             10        10.0            p           yes
# 3             10        11.0            P           yes

# %% [markdown]
# ## Activity

# %% [markdown]
# Let's revisit the titanic data from Wednesday.

# %%
# load titanic data 
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **Activity 1:** Create a new column called `my_alive` based on the original `survived` column. It should be "no" when `survived` is 0, and "yes" when `survived` is 1. Your goal is to make it match the `alive` column which was added by the Seaborn creators.

# %%
titanic['my_alive'] = titanic['survived'].map({0:'no',1:'yes'})
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone my_alive
# 0    man        True  NaN  Southampton    no  False       no
# 1  woman       False    C    Cherbourg   yes  False      yes
# 2  woman       False  NaN  Southampton   yes   True      yes
# 3  woman       False    C  Southampton   yes  False      yes
# 4    man        True  NaN  Southampton    no   True       no

# %%
# run this to check your work
(titanic['my_alive'] == titanic['alive']).all()
# Out:
# True

# %% [markdown]
# **Activity 2:** Create a new column called `my_alone` based on the original `sibsp` and `parch` columns. It should be False if the passenger had any family members on board, True otherwise. Your goal is to make it match the `alone` column which was added by the Seaborn creators.

# %%
titanic['my_alone'] = (titanic['sibsp'] + titanic['parch']) == 0
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone my_alive  my_alone
# 0    man        True  NaN  Southampton    no  False       no     False
# 1  woman       False    C    Cherbourg   yes  False      yes     False
# 2  woman       False  NaN  Southampton   yes   True      yes      True
# 3  woman       False    C  Southampton   yes  False      yes     False
# 4    man        True  NaN  Southampton    no   True       no      True

# %%
# run this to check your work
(titanic['my_alone'] == titanic['alone']).all()
# Out:
# True

# %% [markdown]
# **Activity 3 *CHALLENGE*:** Create a new column called `my_who` based on the original `sex` and `age` columns. If the passenger is under 16, they should be labelled as "child", if they are over 16 and are `sex` "male" they should be labelled "man", and if they are over 16 and are `sex` "female" they should be labelled "woman." Your goal is to make it match the `who` column which was added by the Seaborn creators.
#
# *HINT*: You might find it helpful to split this one up and solve in multiple lines of code.

# %%
titanic['my_who'] = titanic.sex.map({'male':'man','female':'woman'})
titanic['my_who'] = ['child' if titanic.age[i] < 16 else titanic['my_who'][i] for i in range(len(titanic))]
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone my_alive  my_alone my_who
# 0    man        True  NaN  Southampton    no  False       no     False    man
# 1  woman       False    C    Cherbourg   yes  False      yes     False  woman
# 2  woman       False  NaN  Southampton   yes   True      yes      True  woman
# 3  woman       False    C  Southampton   yes  False      yes     False  woman
# 4    man        True  NaN  Southampton    no   True       no      True    man

# %%
# OR
def assign_who(age_and_sex):
    age, sex = age_and_sex
    if age < 16:
        return 'child'
    elif sex == 'male':
        return 'man'
    else:
        return 'woman'
    
titanic['my_who2'] = titanic[['age','sex']].apply(assign_who,axis=1)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone my_alive  my_alone  \
# 0      man        True  NaN  Southampton    no  False       no     False
# 1    woman       False    C    Cherbourg   yes  False      yes     False
# 2    woman       False  NaN  Southampton   yes   True      yes      True
# 3    woman       False    C  Southampton   yes  False      yes     False
# 4      man        True  NaN  Southampton    no   True       no      True
# ..     ...         ...  ...          ...   ...    ...      ...       ...
# 886    man        True  NaN  Southampton    no   True       no      True
# 887  woman       False    B  Southampton   yes   True      yes      True
# 888  woman       False  NaN  Southampton    no  False       no     False
# 889    man        True    C    Cherbourg   yes   True      yes      True
# 890    man        True  NaN   Queenstown    no   True       no      True
#
#     my_who my_who2
# 0      man     man
# 1    woman   woman
# 2    woman   woman
# 3    woman   woman
# 4      man     man
# ..     ...     ...
# 886    man     man
# 887  woman   woman
# 888  woman   woman
# 889    man     man
# 890    man     man
#
# [891 rows x 19 columns]

# %%
# run this to check your work
(titanic['my_who2'] == titanic['who']).all()
# Out:
# True

# %% [markdown]
# ### Code for Discussion Questions

# %%
flights = pd.read_csv('flight_delays.csv')
flights.head()
# Out:
#   Flight_Date            Airline_Name          Origin_City Destination_City  \
# 0  2019-12-03         JetBlue Airways  Fort Lauderdale, FL       Boston, MA
# 1  2019-01-26  American Airlines Inc.        Las Vegas, NV        Miami, FL
# 2  2023-08-25    Alaska Airlines Inc.          Seattle, WA   Pittsburgh, PA
# 3  2021-10-24       Endeavor Air Inc.         New York, NY     Richmond, VA
# 4  2023-02-14    Alaska Airlines Inc.      Los Angeles, CA      Seattle, WA
#
#   Scheduled_Departure_Time Actual_Departure_Time  Departure_Delay_Minutes  \
# 0                    06:10                 06:03                     -7.0
# 1                    12:38                 12:32                     -6.0
# 2                    09:35                 09:27                     -8.0
# 3                    12:43                 12:33                    -10.0
# 4                    10:50                 12:31                    101.0
#
#   Scheduled_Arrival_Time Actual_Arrival_Time  Arrival_Delay_Minutes  \
# 0                  09:14               10:18                   64.0
# 1                  20:20               20:15                   -5.0
# 2                  17:14               16:51                  -23.0
# 3                  14:10               13:51                  -19.0
# 4                  13:48               16:08                  140.0
#
#   Cancelled_Flag Cancellation_Code Diverted_Flag  \
# 0  Not Cancelled     Not Cancelled  Not Diverted
# 1  Not Cancelled     Not Cancelled  Not Diverted
# 2  Not Cancelled     Not Cancelled  Not Diverted
# 3  Not Cancelled     Not Cancelled  Not Diverted
# 4  Not Cancelled     Not Cancelled  Not Diverted
#
#    Scheduled_Elapsed_Time_Minutes  Actual_Elapsed_Time_Minutes  \
# 0                           184.0                        255.0
# 1                           282.0                        283.0
# 2                           279.0                        264.0
# 3                            87.0                         78.0
# 4                           178.0                        217.0
#
#   Carrier_Delay_HH_MM Weather_Delay_HH_MM NAS_Delay_HH_MM  \
# 0               26:04               04:44           01:04
# 1               30:38               14:28           02:50
# 2               08:27               16:37           03:22
# 3               44:52               04:48           04:39
# 4               28:40               21:38           00:39
#
#   Security_Delay_HH_MM Late_Aircraft_Delay_HH_MM
# 0                01:38                     03:37
# 1                04:39                     08:23
# 2                04:52                     01:49
# 3                02:49                     10:38
# 4                04:13                     01:41

# %%
flights['Year'] = flights['Flight_Date'].str.split("-").str[0]

# %%
flights = flights.sort_values(by='Year')

# %%
sns.set(font_scale = 1.8)
fig = sns.displot(data = flights, x  = 'Departure_Delay_Minutes', col = 'Year',binwidth=5)
fig.set(xlim=(-20, 100))
plt.tight_layout()
