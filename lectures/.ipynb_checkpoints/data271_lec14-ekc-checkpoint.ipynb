# %% [markdown]
# # More Pandas
# v.ekc
#
# We are going to continue exploring the dataset of global earthquakes. We will continue slicing DataFrames so that you can get any subset you want! — by data type, by condition, by label — and even do math across entire DataFrames at once. Lastly we will also cover quick plots with Pandas.
#
# **Sections:**
# 1. Setup & Data
# 2. Selecting Columns by Data Type
# 3. Filtering Rows with Boolean Indexing
# 4. Additional Column-Filtering Methods
# 5. Broadcasting & Elementwise Arithmetic
# 6. MultiIndex DataFrames
# 7. Quick Plots with Pandas

# %% [markdown]
# ---
# ## 1. Setup & Data

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# Read the earthquakes dataset
df = pd.read_csv('earthquakes.csv')
df.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %% [markdown]
# ---
# ## 2. Selecting Columns by Data Type: `select_dtypes()`
#
# Sometimes you want only the numeric columns, or only the text columns — without listing them all by name.
#
# #### `select_dtypes()` quick reference
#
# | Argument | What you get |
# |---|---|
# | `object` | String / text columns |
# | `int` | Integer columns only |
# | `float` | Float columns only |
# | `'number'` | All numeric columns (int + float) |
# | `bool` | Boolean columns |

# %%
# Select all columns with object (string) datatypes
df.select_dtypes(object)
# Out:
#      alert        code                                             detail  \
# 0      NaN    37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1      NaN    37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2      NaN    37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3      NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4      NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...    ...         ...                                                ...
# 9327   NaN    73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328   NaN    38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9329   NaN  2018261000  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330   NaN    38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331   NaN    38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#                  ids magType net                             place sources  \
# 0       ,ci37389218,      ml  ci             9km NE of Aguanga, CA    ,ci,
# 1       ,ci37389202,      ml  ci             9km NE of Aguanga, CA    ,ci,
# 2       ,ci37389194,      ml  ci             8km NE of Aguanga, CA    ,ci,
# 3       ,ci37389186,      ml  ci             9km NE of Aguanga, CA    ,ci,
# 4       ,nc73096941,      md  nc             10km NW of Avenal, CA    ,nc,
# ...              ...     ...  ..                               ...     ...
# 9327    ,nc73086771,      md  nc      9km ENE of Mammoth Lakes, CA    ,nc,
# 9328    ,ci38063967,      ml  ci               3km W of Julian, CA    ,ci,
# 9329  ,pr2018261000,      md  pr  35km NNE of Hatillo, Puerto Rico    ,pr,
# 9330    ,ci38063959,      ml  ci             9km NE of Aguanga, CA    ,ci,
# 9331    ,ci38063935,      ml  ci             9km NE of Aguanga, CA    ,ci,
#
#          status                                     title        type  \
# 0     automatic             M 1.4 - 9km NE of Aguanga, CA  earthquake
# 1     automatic             M 1.3 - 9km NE of Aguanga, CA  earthquake
# 2     automatic             M 3.4 - 8km NE of Aguanga, CA  earthquake
# 3     automatic             M 0.4 - 9km NE of Aguanga, CA  earthquake
# 4     automatic             M 2.2 - 10km NW of Avenal, CA  earthquake
# ...         ...                                       ...         ...
# 9327   reviewed      M 0.6 - 9km ENE of Mammoth Lakes, CA  earthquake
# 9328   reviewed               M 1.0 - 3km W of Julian, CA  earthquake
# 9329   reviewed  M 2.4 - 35km NNE of Hatillo, Puerto Rico  earthquake
# 9330   reviewed             M 1.1 - 9km NE of Aguanga, CA  earthquake
# 9331   reviewed             M 0.7 - 9km NE of Aguanga, CA  earthquake
#
#                                                   types  \
# 0            ,geoserve,nearby-cities,origin,phase-data,
# 1            ,geoserve,nearby-cities,origin,phase-data,
# 2     ,dyfi,focal-mechanism,geoserve,nearby-cities,o...
# 3            ,geoserve,nearby-cities,origin,phase-data,
# 4     ,geoserve,nearby-cities,origin,phase-data,scit...
# ...                                                 ...
# 9327         ,geoserve,nearby-cities,origin,phase-data,
# 9328  ,geoserve,nearby-cities,origin,phase-data,scit...
# 9329                       ,geoserve,origin,phase-data,
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin...
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin...
#
#                                                     url
# 0     https://earthquake.usgs.gov/earthquakes/eventp...
# 1     https://earthquake.usgs.gov/earthquakes/eventp...
# 2     https://earthquake.usgs.gov/earthquakes/eventp...
# 3     https://earthquake.usgs.gov/earthquakes/eventp...
# 4     https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                 ...
# 9327  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [9332 rows x 13 columns]

# %%
# Select all columns with integer datatypes
df.select_dtypes(int)
# Out:
#       sig           time  tsunami        updated
# 0      28  1539475168010        0  1539475395144
# 1      26  1539475129610        0  1539475253925
# 2     192  1539475062610        0  1539536756176
# 3       3  1539474978070        0  1539475196167
# 4      72  1539474716050        0  1539477547926
# ...   ...            ...      ...            ...
# 9327    6  1537230228060        0  1537285598315
# 9328   15  1537230135130        0  1537276800970
# 9329   89  1537229908180        0  1537243777410
# 9330   19  1537229545350        0  1537230211640
# 9331    7  1537228864470        0  1537305830770
#
# [9332 rows x 4 columns]

# %%
# Select ALL numeric columns (int + float)
df.select_dtypes('number')
# Out:
#       cdi      dmin  felt    gap   mag  mmi    nst   rms  sig           time  \
# 0     NaN  0.008693   NaN   85.0  1.35  NaN   26.0  0.19   28  1539475168010
# 1     NaN  0.020030   NaN   79.0  1.29  NaN   20.0  0.29   26  1539475129610
# 2     4.4  0.021370  28.0   21.0  3.42  NaN  111.0  0.22  192  1539475062610
# 3     NaN  0.026180   NaN   39.0  0.44  NaN   26.0  0.17    3  1539474978070
# 4     NaN  0.077990   NaN  192.0  2.16  NaN   18.0  0.05   72  1539474716050
# ...   ...       ...   ...    ...   ...  ...    ...   ...  ...            ...
# 9327  NaN  0.018060   NaN  185.0  0.62  NaN   13.0  0.03    6  1537230228060
# 9328  NaN  0.030410   NaN   50.0  1.00  NaN   28.0  0.21   15  1537230135130
# 9329  NaN  0.452600   NaN  276.0  2.40  NaN    9.0  0.41   89  1537229908180
# 9330  NaN  0.018650   NaN   61.0  1.10  NaN   27.0  0.10   19  1537229545350
# 9331  NaN  0.016980   NaN   39.0  0.66  NaN   24.0  0.10    7  1537228864470
#
#       tsunami     tz        updated
# 0           0 -480.0  1539475395144
# 1           0 -480.0  1539475253925
# 2           0 -480.0  1539536756176
# 3           0 -480.0  1539475196167
# 4           0 -480.0  1539477547926
# ...       ...    ...            ...
# 9327        0 -480.0  1537285598315
# 9328        0 -480.0  1537276800970
# 9329        0 -240.0  1537243777410
# 9330        0 -480.0  1537230211640
# 9331        0 -480.0  1537305830770
#
# [9332 rows x 13 columns]

# %% [markdown]
# ---
# ## 3. Filtering Rows with Boolean Indexing
#
# Again, we can create a mask, a **boolean Series**, into `df[...]` or `df.loc[...]` to keep only the rows where the condition is `True`.
#
# We can create a mask using:
# - inequality conditions
# -  more complex conditions
# - 😈 regex to match patterns in string elements 😈
# - numeric elements that are between a range
# - categorical elements that are in a chosen list
#
# | Goal | Syntax |
# |---|---|
# | Single numeric condition | `df[df['col'] >= value]` |
# | OR condition | `df[(cond1) \| (cond2)]` |
# | AND condition | `df[(cond1) & (cond2)]` |
# | String match (exact) | `df[df['col'].str.contains('text')]` |
# | 😈String match (regex) | `df[df['col'].str.contains('pat', regex=True)]` |
# | Numeric range | `df[df['col'].between(a, b, inclusive='both')]` |
# | Match a list of objects | `df[df['col'].isin(['a', 'b'])]` |

# %%
# This tempting syntax does NOT work — you can't compare a column name to a number
# df['mag' >= 7]

# %%
# Correct: keep only rows where magnitude >= 7
df[df['mag'] >= 7]
# Out:
#       alert  cdi      code                                             detail  \
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap                                 ids  mag magType  ...  \
# 837   1.763   3.0  14.0  ,us1000haa3,pt18283003,at00pgehsk,  7.0     mww  ...
# 5263  1.589  18.0  27.0             ,us1000h3p4,us1000h4p4,  7.5     mww  ...
#
#          sources    status           time  \
# 837   ,us,pt,at,  reviewed  1539204500290
# 5263     ,us,us,  reviewed  1538128963480
#
#                                            title  tsunami        type  \
# 837   M 7.0 - 117km E of Kimbe, Papua New Guinea        1  earthquake
# 5263           M 7.5 - 78km N of Palu, Indonesia        1  earthquake
#
#                                                   types     tz        updated  \
# 837   ,dyfi,finite-fault,general-text,geoserve,groun...  600.0  1539378744253
# 5263  ,dyfi,finite-fault,general-text,geoserve,groun...  480.0  1539123134531
#
#                                                     url
# 837   https://earthquake.usgs.gov/earthquakes/eventp...
# 5263  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [2 rows x 26 columns]

# %%
# Multiple conditions with | (OR) and & (AND)
# Select specific columns for earthquakes with mag >= 7 OR that caused a tsunami
df.loc[
    (df.tsunami == 1) | (df.mag >= 7),
    ['mag', 'title', 'tsunami', 'place']
].head(3)
# Out:
#      mag                                              title  tsunami  \
# 36   5.0  M 5.0 - 165km NNW of Flying Fish Cove, Christm...        1
# 118  6.7            M 6.7 - 262km NW of Ozernovskiy, Russia        1
# 501  5.6        M 5.6 - 128km SE of Kimbe, Papua New Guinea        1
#
#                                                place
# 36   165km NNW of Flying Fish Cove, Christmas Island
# 118                  262km NW of Ozernovskiy, Russia
# 501              128km SE of Kimbe, Papua New Guinea

# %%
# str.contains() filters string columns — how many quakes are in California?
df.loc[
    (df.place.str.contains('California')),
    ['mag', 'title', 'tsunami', 'place']
].shape
# Out:
# (124, 4)

# %%
# str.contains() also supports regex — USGS uses both 'CA' and 'California'
CA_df = df.loc[
    (df.place.str.contains('CA|California', regex=True)),
    ['mag', 'title', 'tsunami', 'place']
]
CA_df.shape
# Out:
# (2861, 4)

# %%
# Combining row filter (regex) with column filter (list comprehension)
df.loc[
    (df.place.str.contains('CA|California', regex=True)),
    [col for col in df.columns if 'mag' in col]
].head(3)
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml

# %%
# Same thing, using df.columns.str.contains() for the column selector
df.loc[
    (df.place.str.contains('CA|California', regex=True)),
    df.columns.str.contains('.*mag.*', regex=True)
]
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9326  1.82      ml
# 9327  0.62      md
# 9328  1.00      ml
# 9330  1.10      ml
# 9331  0.66      ml
#
# [2861 rows x 2 columns]

# %%
# .between() filters a numeric column to a range (inclusive on both ends)
df.loc[df.mag.between(6.5, 7.5), ['mag','magType','title','tsunami','type']]

# %%
# .isin() keeps rows where a column value matches any item in a list
df.loc[df.magType.isin(['mw','mwb']), ['mag','magType','title','tsunami','type']]

# %% [markdown]
# ### ✏️ Check-in 1
#
# Using the earthquakes DataFrame:
#
# 1. How many earthquakes had **magnitude between 5.0 and 6.0** (inclusive)?
# 2. Filter to show only earthquakes that are in **Oregon** (the `place` column may say `'OR'` or `'Oregon'` — use regex). Return the Oregon earthquakes and the features `['mag','title','place']`

# %%
# 1. Magnitude between 5.0 and 6.0

# %%
# 2. Oregon earthquakes (regex)

# %% [markdown]
# #### Answer

# %%
# 1.
df[df.mag.between(5.0, 6.0)].shape[0]
# Out:
# 143

# %%
# 2.
df.loc[df.place.str.contains('OR|Oregon', regex=True), ['mag','title','place']]

# %% [markdown]
# ---
# ## 4. Additional Column-Filtering Methods
#
# Beyond selecting specific column names, Pandas gives us `drop()` and `filter()` to remove or select columns by name or pattern — without modifying the original DataFrame.
#
# >**NOTE:** `drop()` and `filter()` both return **a new DataFrame** — they don't change `df`.
# >
# >Use `df.drop/filter(columns=list_of_col_to_drop, inplace=True)` or reassign (`df = df.drop(...)`) if you want to keep the change!

# %%
df.shape
# Out:
# (9332, 26)

# %%
# Drop one column by name
df.drop(columns='ids').shape
# Out:
# (9332, 25)

# %%
# Drop multiple columns at once
df.drop(columns=['ids', 'detail']).shape
# Out:
# (9332, 24)

# %%
# Keep only columns whose names match a regex pattern
df.filter(regex='.*mag.*')
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]

# %%
# Neither drop() nor filter() modifies the original — check:
df.shape

# %% [markdown]
# ---
# ## 5. Broadcasting & Elementwise Arithmetic
#
# Just like NumPy, Pandas supports **broadcasting**: applying a single value (or Series) across an entire DataFrame or Series.
#
# Arithmetic between DataFrames lines up on **labels** (not position), which can cause `NaN` if labels don't match.

# %%
# Broadcast a scalar across a Series
df.mag * 3
# Out:
# 0        4.05
# 1        3.87
# 2       10.26
# 3        1.32
# 4        6.48
#         ...
# 9327     1.86
# 9328     3.00
# 9329     7.20
# 9330     3.30
# 9331     1.98
# Name: mag, Length: 9332, dtype: float64

# %%
# Broadcast a scalar across multiple columns
df[['mag','gap']] * 3
# Out:
#         mag    gap
# 0      4.05  255.0
# 1      3.87  237.0
# 2     10.26   63.0
# 3      1.32  117.0
# 4      6.48  576.0
# ...     ...    ...
# 9327   1.86  555.0
# 9328   3.00  150.0
# 9329   7.20  828.0
# 9330   3.30  183.0
# 9331   1.98  117.0
#
# [9332 rows x 2 columns]

# %% [markdown]
# Example of arithmetic lining up with the row labels, not index position value :|

# %%
# Two DataFrames with partially overlapping labels
df1 = pd.DataFrame({'A':[1,2,3], 'B':[3,4,5], 'C':[5,6,7]})
df2 = pd.DataFrame({'B':[5,6,7], 'C':[7,8,9], 'D':[9,10,11]}, index=[1,2,3])

# %%
df1
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6
# 2  3  5  7

# %%
df2
# Out:
#    B  C   D
# 1  5  7   9
# 2  6  8  10
# 3  7  9  11

# %%
# Elementwise arithmetic aligns on LABELS — mismatches become NaN

print(df1)
print('\n')
print(df2)
print('\n')

df1 + df2
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6
# 2  3  5  7
#
#
#    B  C   D
# 1  5  7   9
# 2  6  8  10
# 3  7  9  11
#     A     B     C   D
# 0 NaN   NaN   NaN NaN
# 1 NaN   9.0  13.0 NaN
# 2 NaN  11.0  15.0 NaN
# 3 NaN   NaN   NaN NaN

# %%
# A Series with matching column labels acts like a row (broadcasts row-wise)
srs = pd.Series([1,2,3], index=['A','B','C'])

print(df1)
print('\n')
print(srs)
print('\n')

df1 + srs
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6
# 2  3  5  7
#
#
# A    1
# B    2
# C    3
# dtype: int64
#    A  B   C
# 0  2  5   8
# 1  3  6   9
# 2  4  7  10

# %%
# Without matching labels, we get NaN everywhere
srs_unlabeled = pd.Series([1,2,3])

print(df1)
print('\n')
print(srs_unlabeled)
print('\n')
df1 + srs_unlabeled
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6
# 2  3  5  7
#
#
# 0    1
# 1    2
# 2    3
# dtype: int64
#     A   B   C   0   1   2
# 0 NaN NaN NaN NaN NaN NaN
# 1 NaN NaN NaN NaN NaN NaN
# 2 NaN NaN NaN NaN NaN NaN

# %%
# To broadcast column-wise (along axis=0), use the arithmetic method with axis=0
print(df1)
print('\n')
print(srs_unlabeled)
print('\n')

df1.add(srs_unlabeled, axis=0)
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6
# 2  3  5  7
#
#
# 0    1
# 1    2
# 2    3
# dtype: int64
#    A  B   C
# 0  2  4   6
# 1  4  6   8
# 2  6  8  10

# %% [markdown]
# ### Arithmetic alignment rules
#
# | Situation | Result |
# |---|---|
# | `df * scalar` | Scalar applied to every element |
# | `df1 + df2` (same labels) | Elementwise addition, aligned by label |
# | `df1 + df2` (different labels) | `NaN` where labels don't match |
# | `df + series` (matching column labels) | Series broadcast **row-wise** |
# | `df.add(series, axis=0)` | Series broadcast column-wise |

# %% [markdown]
# ### ✏️ Check-in 2
#
# The earthquake magnitude scale is logarithmic — each whole number step is 10× more powerful.
#
# 1. Create a new column `mag_energy` that represents a *very rough* energy estimate: `10 ** df['mag']`. *(Broadcasting!)*
# 2. What are the ratioz of the earthquale magnitude to smallest magnitude in the California subset (`CA_df`)? What is the largest ratio?

# %%
# 1. Create mag_energy column

# %%
# 2. Magnitude ratio in CA_df

# %% [markdown]
# #### Hint:

# %% [markdown]
# Use broadcasting to compute `CA_df.mag / CA_df.mag.min()`.

# %% [markdown]
# #### Answer

# %%
# 1.
df['mag_energy'] = 10 ** df['mag']
df[['mag','mag_energy']].head()

# %%
# 2.
cali_df.mag / cali_df.mag.min()

# %% [markdown]
# ---
# ## 6. MultiIndex DataFrames
#
# A **MultiIndex** lets you use two (or more) columns as a hierarchical row index. This makes filtering by nested groups much cleaner.
#
# We'll use the Olympics dataset to illustrate — filtering by **Team** and **Year** simultaneously.

# %%
# Regular DataFrame
olympics = pd.read_csv('athlete_events.csv')
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
# Without MultiIndex: boolean filtering to get US, 2012
olympics[(olympics.Team == 'United States') & (olympics.Year == 2012)]
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 469        256        Abdihakim "Abdi" Abdirahman   M  35.0   178.0    61.0
# 1316       737  Amelia Lynn "Amy" Acuff (-Harvey)   F  37.0   188.0    66.0
# 1455       811   Natalie Cammile Adams (-Brannan)   F  20.0   173.0    65.0
# 1844      1017             Nathan Ghar-Jun Adrian   M  23.0   198.0   100.0
# 1845      1017             Nathan Ghar-Jun Adrian   M  23.0   198.0   100.0
# ...        ...                                ...  ..   ...     ...     ...
# 268357  134271                      Sarah Zelenka   F  25.0   183.0    77.0
# 268621  134388                Julie Ashley Zetlin   F  22.0   168.0    55.0
# 268842  134508                     Lily Ann Zhang   F  16.0   166.0    58.0
# 268843  134508                     Lily Ann Zhang   F  16.0   166.0    58.0
# 269657  134938                 Kate Marie Ziegler   F  24.0   183.0    73.0
#
#                  Team  NOC        Games  Year  Season    City  \
# 469     United States  USA  2012 Summer  2012  Summer  London
# 1316    United States  USA  2012 Summer  2012  Summer  London
# 1455    United States  USA  2012 Summer  2012  Summer  London
# 1844    United States  USA  2012 Summer  2012  Summer  London
# 1845    United States  USA  2012 Summer  2012  Summer  London
# ...               ...  ...          ...   ...     ...     ...
# 268357  United States  USA  2012 Summer  2012  Summer  London
# 268621  United States  USA  2012 Summer  2012  Summer  London
# 268842  United States  USA  2012 Summer  2012  Summer  London
# 268843  United States  USA  2012 Summer  2012  Summer  London
# 269657  United States  USA  2012 Summer  2012  Summer  London
#
#                       Sport                                          Event  \
# 469               Athletics                       Athletics Men's Marathon
# 1316              Athletics                    Athletics Women's High Jump
# 1455               Swimming          Swimming Women's 200 metres Butterfly
# 1844               Swimming            Swimming Men's 100 metres Freestyle
# 1845               Swimming  Swimming Men's 4 x 100 metres Freestyle Relay
# ...                     ...                                            ...
# 268357               Rowing                   Rowing Women's Coxless Pairs
# 268621  Rhythmic Gymnastics         Rhythmic Gymnastics Women's Individual
# 268842         Table Tennis                   Table Tennis Women's Singles
# 268843         Table Tennis                      Table Tennis Women's Team
# 269657             Swimming          Swimming Women's 800 metres Freestyle
#
#          Medal
# 469        NaN
# 1316       NaN
# 1455       NaN
# 1844      Gold
# 1845    Silver
# ...        ...
# 268357     NaN
# 268621     NaN
# 268842     NaN
# 268843     NaN
# 269657     NaN
#
# [669 rows x 15 columns]

# %%
# With MultiIndex: set Team and Year as the index at read time
multi_olympics = pd.read_csv('athlete_events.csv', index_col=['Team','Year'])
multi_olympics.head()
# Out:
#                      ID                      Name Sex   Age  Height  Weight  \
# Team           Year
# China          1992   1                 A Dijiang   M  24.0   180.0    80.0
#                2012   2                  A Lamusi   M  23.0   170.0    60.0
# Denmark        1920   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# Denmark/Sweden 1900   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# Netherlands    1988   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#
#                      NOC        Games  Season       City          Sport  \
# Team           Year
# China          1992  CHN  1992 Summer  Summer  Barcelona     Basketball
#                2012  CHN  2012 Summer  Summer     London           Judo
# Denmark        1920  DEN  1920 Summer  Summer  Antwerpen       Football
# Denmark/Sweden 1900  DEN  1900 Summer  Summer      Paris     Tug-Of-War
# Netherlands    1988  NED  1988 Winter  Winter    Calgary  Speed Skating
#
#                                                 Event Medal
# Team           Year
# China          1992       Basketball Men's Basketball   NaN
#                2012      Judo Men's Extra-Lightweight   NaN
# Denmark        1920           Football Men's Football   NaN
# Denmark/Sweden 1900       Tug-Of-War Men's Tug-Of-War  Gold
# Netherlands    1988  Speed Skating Women's 500 metres   NaN

# %%
# Now indexing is clean: (outer_level, inner_level)
multi_olympics.loc['United States', 2012]
# Out:
# Team           Year
# United States  2012    35.0
#                2012    37.0
#                2012    20.0
#                2012    23.0
#                2012    23.0
#                        ...
#                2012    25.0
#                2012    22.0
#                2012    16.0
#                2012    16.0
#                2012    24.0
# Name: Age, Length: 669, dtype: float64

# %%
# Now indexing is clean: (outer_level, inner_level)
#   grab just the `Age` column!
multi_olympics.loc['United States', 2012]['Age'].mean()
# Out:
# np.float64(26.46188340807175)

# %%
# First level only (all years for a team)
multi_olympics.loc['United States']
# Out:
#           ID                        Name Sex   Age  Height  Weight  NOC  \
# Year
# 1992       6             Per Knut Aaland   M  31.0   188.0    75.0  USA
# 1992       6             Per Knut Aaland   M  31.0   188.0    75.0  USA
# 1992       6             Per Knut Aaland   M  31.0   188.0    75.0  USA
# 1992       6             Per Knut Aaland   M  31.0   188.0    75.0  USA
# 1994       6             Per Knut Aaland   M  33.0   188.0    75.0  USA
# ...      ...                         ...  ..   ...     ...     ...  ...
# 2004  135458                    Rami Zur   M  27.0   175.0    77.0  USA
# 2008  135458                    Rami Zur   M  31.0   175.0    77.0  USA
# 2008  135458                    Rami Zur   M  31.0   175.0    77.0  USA
# 1964  135543  Victor Andrew "Vic" Zwolak   M  25.0   175.0    64.0  USA
# 1972  135566  James Francis "Jim" Zylker   M  21.0   175.0    75.0  USA
#
#             Games  Season         City                 Sport  \
# Year
# 1992  1992 Winter  Winter  Albertville  Cross Country Skiing
# 1992  1992 Winter  Winter  Albertville  Cross Country Skiing
# 1992  1992 Winter  Winter  Albertville  Cross Country Skiing
# 1992  1992 Winter  Winter  Albertville  Cross Country Skiing
# 1994  1994 Winter  Winter  Lillehammer  Cross Country Skiing
# ...           ...     ...          ...                   ...
# 2004  2004 Summer  Summer       Athina              Canoeing
# 2008  2008 Summer  Summer      Beijing              Canoeing
# 2008  2008 Summer  Summer      Beijing              Canoeing
# 1964  1964 Summer  Summer        Tokyo             Athletics
# 1972  1972 Summer  Summer       Munich              Football
#
#                                                   Event Medal
# Year
# 1992           Cross Country Skiing Men's 10 kilometres   NaN
# 1992           Cross Country Skiing Men's 50 kilometres   NaN
# 1992  Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# 1992  Cross Country Skiing Men's 4 x 10 kilometres R...   NaN
# 1994           Cross Country Skiing Men's 10 kilometres   NaN
# ...                                                 ...   ...
# 2004           Canoeing Men's Kayak Doubles, 500 metres   NaN
# 2008           Canoeing Men's Kayak Singles, 500 metres   NaN
# 2008         Canoeing Men's Kayak Singles, 1,000 metres   NaN
# 1964          Athletics Men's 3,000 metres Steeplechase   NaN
# 1972                            Football Men's Football   NaN
#
# [17847 rows x 13 columns]

# %%
# Second level only using slice(None) as a wildcard
multi_olympics.loc[(slice(None), 2012), :]
# Out:
#                      ID                                     Name Sex   Age  \
# Team       Year
# China      2012       2                                 A Lamusi   M  23.0
# France     2012      34       Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0
# Morocco    2012      48                         Abdelhak Aatakni   M  24.0
# Russia     2012      67  Mariya Vasilyevna Abakumova (-Tarabina)   F  26.0
# France     2012      73                                Luc Abalo   M  27.0
# ...                 ...                                      ...  ..   ...
# Hungary    2012  135526                             Dniel Zwickl   M  27.0
# Germany    2012  135528                            Marc Zwiebler   M  28.0
# Kazakhstan 2012  135547            Viktoriya Viktorovna Zyabkina   F  19.0
# Poland     2012  135557                             Dominik ycki   M  38.0
#            2012  135558                       ukasz Tomasz ygado   M  32.0
#
#                  Height  Weight  NOC        Games  Season    City  \
# Team       Year
# China      2012   170.0    60.0  CHN  2012 Summer  Summer  London
# France     2012   187.0    76.0  FRA  2012 Summer  Summer  London
# Morocco    2012     NaN    64.0  MAR  2012 Summer  Summer  London
# Russia     2012   179.0    80.0  RUS  2012 Summer  Summer  London
# France     2012   182.0    86.0  FRA  2012 Summer  Summer  London
# ...                 ...     ...  ...          ...     ...     ...
# Hungary    2012   178.0    71.0  HUN  2012 Summer  Summer  London
# Germany    2012   181.0    75.0  GER  2012 Summer  Summer  London
# Kazakhstan 2012   174.0    62.0  KAZ  2012 Summer  Summer  London
# Poland     2012   192.0    95.0  POL  2012 Summer  Summer  London
#            2012   200.0    89.0  POL  2012 Summer  Summer  London
#
#                         Sport                              Event Medal
# Team       Year
# China      2012          Judo       Judo Men's Extra-Lightweight   NaN
# France     2012     Athletics       Athletics Men's 1,500 metres   NaN
# Morocco    2012        Boxing    Boxing Men's Light-Welterweight   NaN
# Russia     2012     Athletics    Athletics Women's Javelin Throw   NaN
# France     2012      Handball            Handball Men's Handball  Gold
# ...                       ...                                ...   ...
# Hungary    2012  Table Tennis         Table Tennis Men's Singles   NaN
# Germany    2012     Badminton            Badminton Men's Singles   NaN
# Kazakhstan 2012     Athletics       Athletics Women's 200 metres   NaN
# Poland     2012       Sailing  Sailing Men's Two Person Keelboat   NaN
#            2012    Volleyball        Volleyball Men's Volleyball   NaN
#
# [12920 rows x 13 columns]

# %%
# Cleaner to get the inner level:
#    use .xs() to cross-section by a specific level
multi_olympics.xs(key=2012, level='Year')
# Out:
#                 ID                                     Name Sex   Age  Height  \
# Team
# China            2                                 A Lamusi   M  23.0   170.0
# France          34       Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0
# Morocco         48                         Abdelhak Aatakni   M  24.0     NaN
# Russia          67  Mariya Vasilyevna Abakumova (-Tarabina)   F  26.0   179.0
# France          73                                Luc Abalo   M  27.0   182.0
# ...            ...                                      ...  ..   ...     ...
# Hungary     135526                             Dniel Zwickl   M  27.0   178.0
# Germany     135528                            Marc Zwiebler   M  28.0   181.0
# Kazakhstan  135547            Viktoriya Viktorovna Zyabkina   F  19.0   174.0
# Poland      135557                             Dominik ycki   M  38.0   192.0
# Poland      135558                       ukasz Tomasz ygado   M  32.0   200.0
#
#             Weight  NOC        Games  Season    City         Sport  \
# Team
# China         60.0  CHN  2012 Summer  Summer  London          Judo
# France        76.0  FRA  2012 Summer  Summer  London     Athletics
# Morocco       64.0  MAR  2012 Summer  Summer  London        Boxing
# Russia        80.0  RUS  2012 Summer  Summer  London     Athletics
# France        86.0  FRA  2012 Summer  Summer  London      Handball
# ...            ...  ...          ...     ...     ...           ...
# Hungary       71.0  HUN  2012 Summer  Summer  London  Table Tennis
# Germany       75.0  GER  2012 Summer  Summer  London     Badminton
# Kazakhstan    62.0  KAZ  2012 Summer  Summer  London     Athletics
# Poland        95.0  POL  2012 Summer  Summer  London       Sailing
# Poland        89.0  POL  2012 Summer  Summer  London    Volleyball
#
#                                         Event Medal
# Team
# China            Judo Men's Extra-Lightweight   NaN
# France           Athletics Men's 1,500 metres   NaN
# Morocco       Boxing Men's Light-Welterweight   NaN
# Russia        Athletics Women's Javelin Throw   NaN
# France                Handball Men's Handball  Gold
# ...                                       ...   ...
# Hungary            Table Tennis Men's Singles   NaN
# Germany               Badminton Men's Singles   NaN
# Kazakhstan       Athletics Women's 200 metres   NaN
# Poland      Sailing Men's Two Person Keelboat   NaN
# Poland            Volleyball Men's Volleyball   NaN
#
# [12920 rows x 13 columns]

# %%
# Or swap the index levels and then index normally
multi_olympics.swaplevel('Team', 'Year').loc[2012]
# Out:
#                 ID                                     Name Sex   Age  Height  \
# Team
# China            2                                 A Lamusi   M  23.0   170.0
# France          34       Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0
# Morocco         48                         Abdelhak Aatakni   M  24.0     NaN
# Russia          67  Mariya Vasilyevna Abakumova (-Tarabina)   F  26.0   179.0
# France          73                                Luc Abalo   M  27.0   182.0
# ...            ...                                      ...  ..   ...     ...
# Hungary     135526                             Dniel Zwickl   M  27.0   178.0
# Germany     135528                            Marc Zwiebler   M  28.0   181.0
# Kazakhstan  135547            Viktoriya Viktorovna Zyabkina   F  19.0   174.0
# Poland      135557                             Dominik ycki   M  38.0   192.0
# Poland      135558                       ukasz Tomasz ygado   M  32.0   200.0
#
#             Weight  NOC        Games  Season    City         Sport  \
# Team
# China         60.0  CHN  2012 Summer  Summer  London          Judo
# France        76.0  FRA  2012 Summer  Summer  London     Athletics
# Morocco       64.0  MAR  2012 Summer  Summer  London        Boxing
# Russia        80.0  RUS  2012 Summer  Summer  London     Athletics
# France        86.0  FRA  2012 Summer  Summer  London      Handball
# ...            ...  ...          ...     ...     ...           ...
# Hungary       71.0  HUN  2012 Summer  Summer  London  Table Tennis
# Germany       75.0  GER  2012 Summer  Summer  London     Badminton
# Kazakhstan    62.0  KAZ  2012 Summer  Summer  London     Athletics
# Poland        95.0  POL  2012 Summer  Summer  London       Sailing
# Poland        89.0  POL  2012 Summer  Summer  London    Volleyball
#
#                                         Event Medal
# Team
# China            Judo Men's Extra-Lightweight   NaN
# France           Athletics Men's 1,500 metres   NaN
# Morocco       Boxing Men's Light-Welterweight   NaN
# Russia        Athletics Women's Javelin Throw   NaN
# France                Handball Men's Handball  Gold
# ...                                       ...   ...
# Hungary            Table Tennis Men's Singles   NaN
# Germany               Badminton Men's Singles   NaN
# Kazakhstan       Athletics Women's 200 metres   NaN
# Poland      Sailing Men's Two Person Keelboat   NaN
# Poland            Volleyball Men's Volleyball   NaN
#
# [12920 rows x 13 columns]

# %% [markdown]
# ### MultiIndex indexing quick reference
#
# | Goal | Syntax |
# |---|---|
# | Both levels | `df.loc['outer', 'inner']` |
# | Outer level only | `df.loc['outer']` |
# | Inner level only (slice) | `df.loc[(slice(None), 'inner'), :]` |
# | Inner level only (xs) | `df.xs(key='filter_value', level='inner_index_name')` |
# | Swap levels then index | `df.swaplevel('a','b').loc['inner']` |

# %% [markdown]
# ### ✏️ Check-in 3
#
# Using `multi_olympics`:
#
# 1. Retrieve all entries for **Great Britain** (try `'Great Britain'` as the Team).
# 2. Use `.xs()` to get all teams from the **1996** games.
#
# Recall, the outer index is `Team` and the inner index is `Year`

# %%
# 1. Great Britain

# %%
# 2. 1996 Games

# %% [markdown]
# #### Answer

# %%
# 1.
multi_olympics.loc['Great Britain']

# %%
# 2.
multi_olympics.xs(key=1996, level='Year')

# %% [markdown]
# ---
# ## 7. Quick Plots with Pandas
#
# Pandas wraps Matplotlib so you can make exploratory plots directly from a DataFrame — no `import matplotlib` required. The key method is `df.plot(kind=..., x=..., y=...)`.

# %%
# Histogram
df.plot(kind='hist', y='mag');

# %%
# Line plot
df.plot(kind='line', x='time', y='mag');

# %%
# Scatter plot
df.plot(kind='scatter', x='gap', y='mag');

# %%
# Bar chart of value counts
df.value_counts('status').plot(kind='bar');

# %%
# Alternative dot-notation: df.plot.hist(), df.plot.scatter(), etc.
df.plot.hist(y='mag');

# %% [markdown]
# ### `df.plot()` quick reference
#
# | Plot type | `kind=` argument | Alternative notation |
# |---|---|---|
# | Histogram | `'hist'` | `df.plot.hist(y='col')` |
# | Line plot | `'line'` | `df.plot.line(x='col', y='col')` |
# | Scatter plot | `'scatter'` | `df.plot.scatter(x='col', y='col')` |
# | Bar chart | `'bar'` | `df.plot.bar()` |
# | Horizontal bar | `'barh'` | `df.plot.barh()` |
# | Box plot | `'box'` | `df.plot.box()` |

# %% [markdown]
# ---
# ## 8. Putting It All Together
#
# Practice combining filtering, arithmetic, and plotting in one workflow.

# %% [markdown]
# ### **Q1.** Use the `CA_df`, the subsetted DataFrame with only Californian earthquakes.
#
# The summary table will have two rows and 2 columns.
#
# The columns should be `mag` and `place`.
#
# The first row should contain the information for the **smallest** earthquake in California (lowest magnitude) and the second row should contain information for the **largest earthquake** in California.

# %%
# Q1
CA_df.loc[
    [CA_df.mag.idxmin(), CA_df.mag.idxmax()],
    ['mag','place']
]

# %% [markdown]
# #### More hints

# %% [markdown]
# Use `.loc` to reference and subset the columns `mag` and `place`
#
# Since you are using `.loc`, to find the min and max, you want to use the row names, not the index position value!
#
# - `df.colname.idxmin()`
# - `df.colname.idxmax()`

# %% [markdown]
# ### **Q2.** How many earthquakes in the dataset had a **red alert**?

# %%
# Q2
df.alert.value_counts()

#df.alert.value_counts()['red']
# Out:
# alert
# green    58
# red       1
# Name: count, dtype: int64

# %% [markdown]
# ### **Q3.** How many **Oregon** earthquakes are in the dataset?

# %%
# Q3
df.loc[df.place.str.contains('OR|Oregon', regex=True)].shape
# Out:
# (27, 27)

# %% [markdown]
# ### **Q4.** Make a histogram of earthquake magnitude for California only. Use `df.plot()`.

# %%
# Q4
CA_df.mag.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
